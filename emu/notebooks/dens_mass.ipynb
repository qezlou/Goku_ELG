# %% [markdown]
# ## GP emualtor for $n \rightarrow M_{th}$:

# %%
import numpy as np
from gal_goku import plot


plot_hmf_emu = plot.PlotHmfEmu()

seed = 11

savefile = '/home/qezlou/HD2/HETDEX/cosmo/data/HMF/train/26_coeffs/loo_L2_linear_mf_no_merge_on_coeffs.hdf5'

fig, _ = plot_hmf_emu.dens_loo_pred_truth(savefile)
# Out:
# (36, 25)

# %%
a = np.arange(10)
a[::-1]
# Out:
# array([9, 8, 7, 6, 5, 4, 3, 2, 1, 0])

# %%
0.20 * 1e-3
# Out:
# 0.0002
