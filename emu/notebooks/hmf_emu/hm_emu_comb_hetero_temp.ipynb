# %%
import numpy as np
import importlib
from gal_goku import plot
importlib.reload(plot)
data_dir = '/home/qezlou/HD2/HETDEX/cosmo/data/'
train_subdir = 'HMF/train_learn_hetero_pca_l14_full_comp_kernel_more_massive'
num_inducing = 500
num_latents = 14
noise_num_latents = 10
epochs = 12_000
z = 0.0

sims = np.arange(36)
#sims = np.delete(sims, [2, 12, 18, 20])
composite_kernel=['matern32','matern52', 'matern32', 'matern52']

mass_range = (11.1, 13.7)
plot_hmf_emu = plot.HmfCombined(sims=sims, z=z, data_dir=data_dir, 
                                train_subdir=train_subdir, num_inducing=num_inducing, 
                                num_latents=num_latents, noise_num_latents=noise_num_latents, 
                                epochs=epochs, composite_kernel=composite_kernel, mass_range=mass_range)
#savefig='/home/qezlou/HD2/HETDEX/draft/gal-emu-paper/figures/hmf_loocv_het_2gp.pdf'
savefig=None
plot_hmf_emu.err_all(sample_size=3, add_text=False, log_scale=False,savefig=savefig)
# Out:
# halo_tools not available, won't be able to use propagator.
# 2026-02-02 10:43:09.446596: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1770050589.462463  339106 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1770050589.467586  339106 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1770050589.480649  339106 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
import numpy as np
import importlib
from gal_goku import plot
importlib.reload(plot)
data_dir = '/home/qezlou/HD2/HETDEX/cosmo/data/'
train_subdirs = ['HMF/train_learn_hetero_pca_l14_full_comp_kernel_more_massive',
                 'HMF/train_learn_hetero_pca_l14_full_comp_kernel_more_massive',
                 'HMF/train_learn_hetero_pca_l14_full_comp_kernel',
                 'HMF/train_learn_hetero_pca_l14_full_comp_kernel']
num_inducing = 500
num_latents = 14
noise_num_latents = 10
epochs = 12_000
zs = [0.0,1.0, 2.0, 3.0]

sims = np.arange(36)
#sims = np.delete(sims, [2, 12, 18, 20])
composite_kernel=['matern32','matern52', 'matern32', 'matern52']

fig_err, fig_rel_err =plot.hmf_loo_zs(data_dir=data_dir, train_subdirs=train_subdirs, zs=zs,
                        num_inducing=num_inducing, num_latents=num_latents,
                        noise_num_latents=noise_num_latents, epochs=epochs,
                        composite_kernel=composite_kernel)
savefig = '/home/qezlou/HD2/HETDEX/draft/gal-emu-paper/figures/hmf_loocv_het_2gp_all-zs_err.pdf'
fig_err.savefig(savefig)
savefig = '/home/qezlou/HD2/HETDEX/draft/gal-emu-paper/figures/hmf_loocv_het_2gp_all-zs_rel_err.pdf'
fig_rel_err.savefig(savefig)
# Out:
# z = 0.0, mass_range = (11.1, 13.7)
# 2026-02-02 10:57:15.555479: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 2026-02-02 10:57:15.560653: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 2026-02-02 10:57:15.604366: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 2026-02-02 10:57:15.611582: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 2026-02-02 10:57:15.612031: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# ...
