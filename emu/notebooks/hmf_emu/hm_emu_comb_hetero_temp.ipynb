# %%
import numpy as np
import importlib
from gal_goku import plot
importlib.reload(plot)
data_dir = '/home/qezlou/HD2/HETDEX/cosmo/data/'
train_subdir = 'HMF/train_learn_hetero_pca_l14_full_comp_kernel_more_massive'
num_inducing = 500
num_latents = 14
noise_num_latents = 10
epochs = 12_000
z = 0.0

sims = np.arange(36)
#sims = np.delete(sims, [2, 12, 18, 20])
composite_kernel=['matern32','matern52', 'matern32', 'matern52']

mass_range = (11.1, 13.7)
plot_hmf_emu = plot.HmfCombined(sims=sims, z=z, data_dir=data_dir, 
                                train_subdir=train_subdir, num_inducing=num_inducing, 
                                num_latents=num_latents, noise_num_latents=noise_num_latents, 
                                epochs=epochs, composite_kernel=composite_kernel, mass_range=mass_range)
#savefig='/home/qezlou/HD2/HETDEX/draft/gal-emu-paper/figures/hmf_loocv_het_2gp.pdf'
savefig=None
plot_hmf_emu.err_all(sample_size=3, add_text=False, log_scale=False,savefig=savefig)
# Out:
# halo_tools not available, won't be able to use propagator.
# 2026-02-02 07:51:00.434524: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1770040260.450353  319847 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1770040260.455502  319847 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1770040260.468533  319847 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1770040260.468546  319847 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1770040260.468548  319847 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1770040260.468549  319847 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-02-02 07:51:00.472556: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /home/qezlou/HD2/HETDEX/cosmo/pack_dev/.gal_venv/lib/python3.11/site-packages/keras/src/export/tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):
# /home/qezlou/HD2/HETDEX/cosmo/pack_dev/.gal_venv/lib/python3.11/site-packages/gpflow/versions.py:1: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# mass_range : (11.1, 13.7)
# mass_range : (11.1, 13.7)
# mass_range : (11.1, 13.7)
# mass_range : (11.1, 13.7)
# 2026-02-02 07:51:04.834461: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 2026-02-02 07:51:04.843757: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 2026-02-02 07:51:04.868236: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 2026-02-02 07:51:04.868453: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 2026-02-02 07:51:04.872673: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 2026-02-02 07:51:04.874805: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 2026-02-02 07:51:04.880398: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 2026-02-02 07:51:04.883041: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 2026-02-02 07:51:04.890079: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 2026-02-02 07:51:04.892474: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 02/02/2026 07:51:59 AM Number of sims with LOO predictions: 36
# 02/02/2026 07:51:59 AM Plotting the fractional error for all sims, (36, 26), (36, 26)
# Simulations with |(pred - truth) / sigma_pred| > 4: (array([], dtype=int64),)
# Simulations with |(pred - truth) / sigma_pred| > 3: (array([], dtype=int64),)

# %%
import numpy as np
import importlib
from gal_goku import plot
importlib.reload(plot)
data_dir = '/home/qezlou/HD2/HETDEX/cosmo/data/'
train_subdirs = ['HMF/train_learn_hetero_pca_l14_full_comp_kernel_more_massive',
                 'HMF/train_learn_hetero_pca_l14_full_comp_kernel',
                 'HMF/train_learn_hetero_pca_l14_full_comp_kernel']
num_inducing = 500
num_latents = 14
noise_num_latents = 10
epochs = 12_000
zs = [0.0, 2.0, 3.0]

sims = np.arange(36)
#sims = np.delete(sims, [2, 12, 18, 20])
composite_kernel=['matern32','matern52', 'matern32', 'matern52']

fig_err, fig_rel_err =plot.hmf_loo_zs(data_dir=data_dir, train_subdirs=train_subdirs, zs=zs,
                        num_inducing=num_inducing, num_latents=num_latents,
                        noise_num_latents=noise_num_latents, epochs=epochs,
                        composite_kernel=composite_kernel)
savefig = '/home/qezlou/HD2/HETDEX/draft/gal-emu-paper/figures/hmf_loocv_het_2gp_all-zs_err.pdf'
fig_err.savefig(savefig)
savefig = '/home/qezlou/HD2/HETDEX/draft/gal-emu-paper/figures/hmf_loocv_het_2gp_all-zs_rel_err.pdf'
fig_rel_err.savefig(savefig)
# Out:
# halo_tools not available, won't be able to use propagator.
# 2026-02-02 08:25:07.064117: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1770042307.079805  329959 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1770042307.084865  329959 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1770042307.097814  329959 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1770042307.097827  329959 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1770042307.097828  329959 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1770042307.097830  329959 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-02-02 08:25:07.101679: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /home/qezlou/HD2/HETDEX/cosmo/pack_dev/.gal_venv/lib/python3.11/site-packages/keras/src/export/tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):
# /home/qezlou/HD2/HETDEX/cosmo/pack_dev/.gal_venv/lib/python3.11/site-packages/gpflow/versions.py:1: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# z = 0.0, mass_range = (11.1, 13.7)
# 2026-02-02 08:25:11.480175: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 2026-02-02 08:25:11.494207: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 2026-02-02 08:25:11.521546: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 2026-02-02 08:25:11.522423: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 2026-02-02 08:25:11.530375: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 2026-02-02 08:25:11.532048: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 2026-02-02 08:25:11.532641: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 2026-02-02 08:25:11.540166: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 2026-02-02 08:25:11.544039: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 2026-02-02 08:25:11.544037: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 02/02/2026 08:26:05 AM Number of sims with LOO predictions: 36
# z = 2.0, mass_range = (11.1, 12.5)
# 2026-02-02 08:26:05.584438: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 2026-02-02 08:26:05.598744: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 2026-02-02 08:26:05.602819: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 2026-02-02 08:26:05.614246: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 2026-02-02 08:26:05.629289: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 2026-02-02 08:26:05.629471: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 2026-02-02 08:26:05.631755: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 2026-02-02 08:26:05.634236: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 2026-02-02 08:26:05.639805: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 2026-02-02 08:26:05.641473: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 02/02/2026 08:26:59 AM Number of sims with LOO predictions: 36
# 02/02/2026 08:26:59 AM Number of sims with LOO predictions: 36
# z = 3.0, mass_range = (11.1, 12.5)
# 2026-02-02 08:27:00.478556: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 2026-02-02 08:27:00.483712: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 2026-02-02 08:27:00.499018: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 2026-02-02 08:27:00.510051: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 2026-02-02 08:27:00.519569: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 2026-02-02 08:27:00.523017: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 2026-02-02 08:27:00.525531: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 2026-02-02 08:27:00.526998: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 2026-02-02 08:27:00.529042: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 2026-02-02 08:27:00.529089: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 02/02/2026 08:27:55 AM Number of sims with LOO predictions: 36
# 02/02/2026 08:27:55 AM Number of sims with LOO predictions: 36
# 02/02/2026 08:27:55 AM Number of sims with LOO predictions: 36
