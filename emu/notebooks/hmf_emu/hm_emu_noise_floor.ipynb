# %%
import numpy as np
import importlib
from gal_goku import plot
importlib.reload(plot)
data_dir = '/home/qezlou/HD2/HETDEX/cosmo/data/'
train_subdir = 'HMF/train_noise_floor/'
num_inducing = 500
num_latents = 14
epochs = 12_000


sims = np.arange(36)


composite_kernel = ['matern32', 'matern52', 'matern32', 'matern52']
norm_type = 'subtract_mean'  # Options could be 'subtract_mean' or 'std_gaussian'

plot_hmf_emu = plot.HmfCombined(sims=sims, data_dir=data_dir, train_subdir=train_subdir, num_inducing=num_inducing, num_latents=num_latents, epochs=epochs, composite_kernel=composite_kernel, norm_type=norm_type, logging_level='INFO')



_ = plot_hmf_emu.pred_vs_trtuh()
# Out:
# 2025-10-20 13:19:51.438583: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-10-20 13:19:51.441775: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-10-20 13:19:51.451164: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1760984391.466447  513528 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1760984391.471284  513528 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1760984391.483635  513528 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1760984391.483646  513528 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1760984391.483648  513528 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1760984391.483649  513528 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-10-20 13:19:51.487557: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# summary_stats | 10/20/2025 01:19:54 PM | Rank 0 | INFO  |  loading from L2_hmfs_2.5_no_merge.hdf5
# summary_stats | 10/20/2025 01:19:54 PM | Rank 0 | INFO  |  loading from L2_hmfs_2.5_narrow_no_merge.hdf5
# summary_stats | 10/20/2025 01:19:54 PM | Rank 0 | INFO  |  loading from L2_hmfs_2.5_narrow_no_merge.hdf5
# summary_stats | 10/20/2025 01:19:54 PM | Rank 0 | INFO  |  loading from HF_hmfs_2.5_no_merge.hdf5
# summary_stats | 10/20/2025 01:19:54 PM | Rank 0 | INFO  |  loading from HF_hmfs_2.5_no_merge.hdf5
# summary_stats | 10/20/2025 01:19:54 PM | Rank 0 | INFO  |  loading from HF_hmfs_2.5_no_merge.hdf5
# summary_stats | 10/20/2025 01:19:54 PM | Rank 0 | INFO  |  loading from HF_hmfs_2.5_narrow_no_merge.hdf5
# summary_stats | 10/20/2025 01:19:54 PM | Rank 0 | INFO  |  loading from HF_hmfs_2.5_narrow_no_merge.hdf5
# summary_stats | 10/20/2025 01:19:54 PM | Rank 0 | INFO  |  loading from HF_hmfs_2.5_narrow_no_merge.hdf5
# summary_stats | 10/20/2025 01:19:54 PM | Rank 0 | INFO  |  loading from HF_hmfs_2.5_narrow_no_merge.hdf5
# HMF-MFCoregEmu | 10/20/2025 01:19:54 PM | Rank 0 | INFO  |  Normalizing X between 0 and 1, subtracting the mean of LF from LF Y
# HMF-MFCoregEmu | 10/20/2025 01:19:54 PM | Rank 0 | INFO  |  norm_type subtract_mean
# HMF-MFCoregEmu | 10/20/2025 01:19:54 PM | Rank 0 | INFO  |  noise_floor 0.0
# 10/20/2025 01:19:54 PM Getting the predictions
# 10/20/2025 01:19:54 PM Using 10 cores for parallel prediction
# 🔹 Initializing W with structured diagonal correlations
# 🔹 Initializing W with structured diagonal correlations
# 🔹 Initializing W with structured diagonal correlations

# %%
import numpy as np
import importlib
from gal_goku import plot
importlib.reload(plot)
data_dir = '/home/qezlou/HD2/HETDEX/cosmo/data/'
train_subdir = 'HMF/train_noise_floor/'
num_inducing = 500
num_latents = 14
epochs = 12_000


sims = np.arange(36)
sims = np.delete(sims, [2, 18, 20])

composite_kernel = ['matern32', 'matern52', 'matern32', 'matern52']
norm_type = 'subtract_mean'  # Options could be 'subtract_mean' or 'std_gaussian'


plot_hmf_emu = plot.HmfCombined(sims=sims, data_dir=data_dir, train_subdir=train_subdir, num_inducing=num_inducing, num_latents=num_latents, epochs=epochs, composite_kernel=composite_kernel, norm_type=norm_type)

#savefig='/home/qezlou/HD2/HETDEX/draft/gal-emu-paper/figures/hmf_loocv.pdf'
savefig=None
plot_hmf_emu.err_all(sample_size=5, add_text=False, log_scale=False,savefig=savefig)
# Out:
# 2025-10-16 09:45:12.806869: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-10-16 09:45:12.811418: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-10-16 09:45:12.825722: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1760625912.851360  386311 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1760625912.858931  386311 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1760625912.877299  386311 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1760625912.877327  386311 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1760625912.877329  386311 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1760625912.877331  386311 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-10-16 09:45:12.883471: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# summary_stats | 10/16/2025 09:45:18 AM | Rank 0 | INFO  |  loading from L2_hmfs_2.5_no_merge.hdf5
# summary_stats | 10/16/2025 09:45:18 AM | Rank 0 | INFO  |  loading from L2_hmfs_2.5_narrow_no_merge.hdf5
# summary_stats | 10/16/2025 09:45:18 AM | Rank 0 | INFO  |  loading from L2_hmfs_2.5_narrow_no_merge.hdf5
# summary_stats | 10/16/2025 09:45:18 AM | Rank 0 | INFO  |  loading from HF_hmfs_2.5_no_merge.hdf5
# summary_stats | 10/16/2025 09:45:18 AM | Rank 0 | INFO  |  loading from HF_hmfs_2.5_no_merge.hdf5
# summary_stats | 10/16/2025 09:45:18 AM | Rank 0 | INFO  |  loading from HF_hmfs_2.5_no_merge.hdf5
# summary_stats | 10/16/2025 09:45:18 AM | Rank 0 | INFO  |  loading from HF_hmfs_2.5_narrow_no_merge.hdf5
# summary_stats | 10/16/2025 09:45:18 AM | Rank 0 | INFO  |  loading from HF_hmfs_2.5_narrow_no_merge.hdf5
# summary_stats | 10/16/2025 09:45:18 AM | Rank 0 | INFO  |  loading from HF_hmfs_2.5_narrow_no_merge.hdf5
# summary_stats | 10/16/2025 09:45:18 AM | Rank 0 | INFO  |  loading from HF_hmfs_2.5_narrow_no_merge.hdf5
# 10/16/2025 09:45:18 AM Getting the predictions
# 10/16/2025 09:45:18 AM Using 10 cores for parallel prediction
# 🔹 Initializing W with structured diagonal correlations
# 🔹 Initializing W with structured diagonal correlations
# 2025-10-16 09:45:18.649008: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 2025-10-16 09:45:18.733910: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 2025-10-16 09:45:18.779596: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 2025-10-16 09:45:18.784492: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 2025-10-16 09:45:18.796833: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 2025-10-16 09:45:18.803005: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 2025-10-16 09:45:18.814715: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 2025-10-16 09:45:18.816751: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 2025-10-16 09:45:18.823546: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 2025-10-16 09:45:18.831184: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 🔹 Initializing W with structured diagonal correlations
# 🔹 Initializing W with structured diagonal correlations
# 🔹 Initializing W with structured diagonal correlations
# 🔹 Initializing W with structured diagonal correlations
# 🔹 Initializing W with structured diagonal correlations
# 🔹 Initializing W with structured diagonal correlations🔹 Initializing W with structured diagonal correlations
#
# 🔹 Initializing W with structured diagonal correlations
# 🔹 Using Heteroscedastic Gaussian likelihood
# 🔹 Using Heteroscedastic Gaussian likelihood
# 🔹 Using Heteroscedastic Gaussian likelihood
# 🔹 Using Heteroscedastic Gaussian likelihood
# 🔹 Using Heteroscedastic Gaussian likelihood
# 🔹 Using Heteroscedastic Gaussian likelihood
# 🔹 Using Heteroscedastic Gaussian likelihood
# 🔹 Using Heteroscedastic Gaussian likelihood
# 🔹 Using Heteroscedastic Gaussian likelihood
# 🔹 Using Heteroscedastic Gaussian likelihood
# 🔹 Initializing W with structured diagonal correlations
# 🔹 Using Heteroscedastic Gaussian likelihood
# 🔹 Initializing W with structured diagonal correlations
# 🔹 Using Heteroscedastic Gaussian likelihood
# 🔹 Initializing W with structured diagonal correlations
# 🔹 Using Heteroscedastic Gaussian likelihood
# 🔹 Initializing W with structured diagonal correlations
# 🔹 Using Heteroscedastic Gaussian likelihood
# 🔹 Initializing W with structured diagonal correlations
# 🔹 Initializing W with structured diagonal correlations
# 🔹 Initializing W with structured diagonal correlations
# 🔹 Initializing W with structured diagonal correlations
# 🔹 Using Heteroscedastic Gaussian likelihood
# 🔹 Using Heteroscedastic Gaussian likelihood
# 🔹 Using Heteroscedastic Gaussian likelihood
# 🔹 Using Heteroscedastic Gaussian likelihood
# 🔹 Initializing W with structured diagonal correlations
# 🔹 Initializing W with structured diagonal correlations
# 🔹 Using Heteroscedastic Gaussian likelihood
# 🔹 Using Heteroscedastic Gaussian likelihood
# 🔹 Initializing W with structured diagonal correlations
# 🔹 Initializing W with structured diagonal correlations
# 🔹 Using Heteroscedastic Gaussian likelihood
# 🔹 Initializing W with structured diagonal correlations
# 🔹 Using Heteroscedastic Gaussian likelihood
# 🔹 Using Heteroscedastic Gaussian likelihood
# 🔹 Initializing W with structured diagonal correlations
# 🔹 Initializing W with structured diagonal correlations
# 🔹 Initializing W with structured diagonal correlations
# 🔹 Using Heteroscedastic Gaussian likelihood
# 🔹 Initializing W with structured diagonal correlations
# 🔹 Using Heteroscedastic Gaussian likelihood
# 🔹 Using Heteroscedastic Gaussian likelihood
# 🔹 Using Heteroscedastic Gaussian likelihood
# 🔹 Initializing W with structured diagonal correlations
# 🔹 Using Heteroscedastic Gaussian likelihood
# 🔹 Initializing W with structured diagonal correlations
# 🔹 Using Heteroscedastic Gaussian likelihood
# 🔹 Initializing W with structured diagonal correlations
# 🔹 Using Heteroscedastic Gaussian likelihood
# 🔹 Initializing W with structured diagonal correlations
# 🔹 Using Heteroscedastic Gaussian likelihood
# 🔹 Initializing W with structured diagonal correlations
# 🔹 Initializing W with structured diagonal correlations
# 🔹 Using Heteroscedastic Gaussian likelihood🔹 Using Heteroscedastic Gaussian likelihood
#
# truth_uncen = (33, 14)

# %%
import numpy as np

10**(np.abs(1.05 * -2))
# Out:
# np.float64(125.89254117941675)

# %%
np.log(20/10)
# Out:
# np.float64(0.6931471805599453)

# %%
np.log(200)/np.log(2) - 1
# Out:
# np.float64(6.643856189774724)

# %%
200/2 - 1
# Out:
# 99.0
