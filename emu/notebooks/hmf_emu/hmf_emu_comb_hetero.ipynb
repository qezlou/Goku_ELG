# %%
import mfgpflow
mfgpflow.__file__
# Out:
# '/home/qezlou/HD2/HETDEX/cosmo/pack_dev/multi_fidelity_gpflow/mfgpflow/__init__.py'

# %%
import numpy as np
import importlib
from gal_goku import plot
importlib.reload(plot)
data_dir = '/home/qezlou/HD2/HETDEX/cosmo/data/'
train_subdir = 'HMF/train_learn_hetero_pca_l14_full_comp_kernel'
num_inducing = 500
num_latents = 14
noise_num_latents = 10
epochs = 12_000
z = 2.5

sims = np.arange(36)
#sims = np.delete(sims, [2, 12, 18, 20])
composite_kernel=['matern32','matern52', 'matern32', 'matern52']


plot_hmf_emu = plot.HmfCombined(sims=sims, z=z, data_dir=data_dir, 
                                train_subdir=train_subdir, num_inducing=num_inducing, 
                                num_latents=num_latents, noise_num_latents=noise_num_latents, 
                                epochs=epochs, composite_kernel=composite_kernel)

#savefig='/home/qezlou/HD2/HETDEX/draft/gal-emu-paper/figures/hmf_loocv.pdf'
savefig=None
plot_hmf_emu.err_all(sample_size=3, add_text=False, log_scale=False,savefig=savefig)
# Out:
# 2025-12-31 19:55:14.338238: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 2025-12-31 19:55:14.367844: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 2025-12-31 19:55:14.392095: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 2025-12-31 19:55:14.394322: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 2025-12-31 19:55:14.396295: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# ...

# %%
import numpy as np
import importlib
from gal_goku import plot
importlib.reload(plot)
data_dir = '/home/qezlou/HD2/HETDEX/cosmo/data/'
train_subdir = 'HMF/train_learn_hetero_pca_l14_full_comp_kernel'
num_inducing = 500
num_latents = 14
noise_num_latents = 10
epochs = 12_000
z = 2.5

sims = np.array([2, 12, 18, 20])
composite_kernel=['matern32','matern52', 'matern32', 'matern52']


plot_hmf_emu = plot.HmfCombined(sims=sims, z=z, data_dir=data_dir, 
                                train_subdir=train_subdir, num_inducing=num_inducing, 
                                num_latents=num_latents, noise_num_latents=noise_num_latents, 
                                epochs=epochs, composite_kernel=composite_kernel)

#savefig='/home/qezlou/HD2/HETDEX/draft/gal-emu-paper/figures/hmf_loocv.pdf'
savefig=None
plot_hmf_emu.err_all(sample_size=4, add_text=False, log_scale=False,savefig=savefig, legend_frac=True)
# Out:
# 12/31/2025 06:23:07 PM Getting the predictions
# 12/31/2025 06:23:07 PM Getting the predictions
# 12/31/2025 06:23:07 PM Getting the predictions
# 12/31/2025 06:23:07 PM Getting the predictions
# 12/31/2025 06:23:07 PM Getting the predictions
# 12/31/2025 06:23:07 PM Getting the predictions
# 12/31/2025 06:23:07 PM Getting the predictions
# 12/31/2025 06:23:07 PM Getting the predictions
# 12/31/2025 06:23:07 PM Getting the predictions
# 12/31/2025 06:23:07 PM Using 10 cores for parallel prediction
# 12/31/2025 06:23:07 PM Using 10 cores for parallel prediction
# 12/31/2025 06:23:07 PM Using 10 cores for parallel prediction
# 12/31/2025 06:23:07 PM Using 10 cores for parallel prediction
# 12/31/2025 06:23:07 PM Using 10 cores for parallel prediction
# 12/31/2025 06:23:07 PM Using 10 cores for parallel prediction
# 12/31/2025 06:23:07 PM Using 10 cores for parallel prediction
# 12/31/2025 06:23:07 PM Using 10 cores for parallel prediction
# ...

# %% [markdown]
# Humm:
# - Only 2 and 18 don't look great (low $\Omega_m$ and $n_s$)

# %%
import numpy as np
import importlib
from gal_goku import plot
importlib.reload(plot)
data_dir = '/home/qezlou/HD2/HETDEX/cosmo/data/'
train_subdir = 'HMF/train_learn_hetero_pca_l14_full_comp_kernel'
num_inducing = 500
num_latents = 14
noise_num_latents = 10
epochs = 12_000
z = 2.5

sims = np.arange(36)
sims = np.delete(sims, [2, 18])
composite_kernel=['matern32','matern52', 'matern32', 'matern52']


plot_hmf_emu = plot.HmfCombined(sims=sims, z=z, data_dir=data_dir, 
                                train_subdir=train_subdir, num_inducing=num_inducing, 
                                num_latents=num_latents, noise_num_latents=noise_num_latents, 
                                epochs=epochs, composite_kernel=composite_kernel)

#savefig='/home/qezlou/HD2/HETDEX/draft/gal-emu-paper/figures/hmf_loocv.pdf'
savefig=None
plot_hmf_emu.err_all(sample_size=3, add_text=False, log_scale=False,savefig=savefig)
# Out:
# 2025-12-31 19:56:07.764551: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 2025-12-31 19:56:07.766144: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 2025-12-31 19:56:07.802088: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 2025-12-31 19:56:07.802087: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 2025-12-31 19:56:07.805568: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# ...

# %%
import numpy as np
import importlib
from gal_goku import plot
importlib.reload(plot)
data_dir = '/home/qezlou/HD2/HETDEX/cosmo/data/'
train_subdir = 'HMF/train_learn_hetero_pca_l14_full_comp_kernel'
num_inducing = 500
num_latents = 14
noise_num_latents = 10
epochs = 12_000
z = 2.5

sims = np.arange(36)
sims = np.delete(sims, [19])
composite_kernel = ['matern32', 'matern52', 'matern32', 'matern52']

plot_hmf_emu = plot.HmfCombined(sims=sims, z=z, data_dir=data_dir, train_subdir=train_subdir, num_inducing=num_inducing, num_latents=num_latents, epochs=epochs, composite_kernel=composite_kernel)



_ = plot_hmf_emu.pred_vs_trtuh()
# Out:
# 2025-12-31 19:57:00.120699: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 2025-12-31 19:57:00.122966: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 2025-12-31 19:57:00.144877: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 2025-12-31 19:57:00.158110: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 2025-12-31 19:57:00.159420: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# ...

# %% [markdown]
# ### Explore proepr error to show:
