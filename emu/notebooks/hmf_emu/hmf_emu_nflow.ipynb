# %%
import importlib
from gal_goku import plot
importlib.reload(plot)
import numpy as np


train_subdir = "HMF/train_nflow_lf_mean"
norm_type = "subtract_mean"
data_dir = "/home/qezlou/HD2/HETDEX/cosmo/data/"
z = 2.5
noise_floor = 0

sims = np.array([0])

plot_hmf_emu = plot.HmfCombined(data_dir=data_dir, 
                                sims=sims, 
                                z=z,
                                train_subdir=train_subdir,
                                logging_level='INFO')
# Out:
# halo_tools not available, won't be able to use propagator.
# [timer] predict: load attrs 0.00s
# [timer] predict: build/restore model 0.70s (device=cpu)
# [timer] predict: load checkpoint 0.04s
# samples.shape: (1, 256, 14)
# [timer] predict: sampling + moments 0.06s (num_samples=256)
# 01/19/2026 03:49:08 PM Number of sims with LOO predictions: 1

# %%
savefig=None
plot_hmf_emu.err_all(sample_size=3, add_text=False, log_scale=False,savefig=savefig)
# Out:
# 01/19/2026 03:49:08 PM Plotting the fractional error for all sims, (1, 14), (1, 14)

# %% [markdown]
# Seems like too large `mean_hidden_params` overfits (bad loo) and too small `mean_weight` also pushes the LOO higher.
