# %%
import importlib
from gal_goku import plot
importlib.reload(plot)
import numpy as np


train_subdir = "HMF/train_nflow"
norm_type = "subtract_mean"
data_dir = "/home/qezlou/HD2/HETDEX/cosmo/data/"
z = 2.5
noise_floor = 0

sims = np.arange(4)

plot_hmf_emu = plot.HmfCombined(data_dir=data_dir, 
                                sims=sims, 
                                z=z,
                                train_subdir=train_subdir,
                                logging_level='INFO')
# Out:
# halo_tools not available, won't be able to use propagator.
# [timer] predict: load attrs 0.00s
# [timer] predict: build/restore model 0.75s (device=cpu)
# [timer] predict: load checkpoint 0.06s
# samples.shape: (1, 256, 14)
# [timer] predict: sampling + moments 0.10s (num_samples=256)
# [timer] predict: load attrs 0.00s
# [timer] predict: build/restore model 0.00s (device=cpu)
# [timer] predict: load checkpoint 0.05s
# samples.shape: (1, 256, 14)
# [timer] predict: sampling + moments 0.11s (num_samples=256)
# [timer] predict: load attrs 0.00s
# [timer] predict: build/restore model 0.00s (device=cpu)
# [timer] predict: load checkpoint 0.05s
# samples.shape: (1, 256, 14)
# [timer] predict: sampling + moments 0.10s (num_samples=256)
# [timer] predict: load attrs 0.00s
# [timer] predict: build/restore model 0.00s (device=cpu)
# [timer] predict: load checkpoint 0.05s
# samples.shape: (1, 256, 14)
# [timer] predict: sampling + moments 0.10s (num_samples=256)
# 01/03/2026 05:34:58 PM Number of sims with LOO predictions: 4

# %%
savefig=None
plot_hmf_emu.err_all(sample_size=3, add_text=False, log_scale=False,savefig=savefig)
# Out:
# 01/03/2026 05:35:00 PM Plotting the fractional error for all sims, (4, 14), (4, 14)
