# %%
import numpy as np
from gal_goku import plot


plot_hmf_emu = plot.PlotHmfEmu()

seed = 23

savefile = '/home/qezlou/HD2/HETDEX/cosmo/data/HMF/train/loo_L2_no_merge.hdf5'
fig, _ = plot_hmf_emu.loo_pred_truth(savefile=savefile, sub_sample=10, seed=seed)
fig.suptitle('Remove last bins with counts < 20 | GPFlow')
fig.tight_layout()

savefile = '/home/qezlou/HD2/HETDEX/cosmo/data/HMF/train/loo_L2_GPy_no_merge.hdf5'
fig, _ = plot_hmf_emu.loo_pred_truth(savefile=savefile, sub_sample=10, seed=seed)
fig.suptitle('LOO errors , reoptimization=1000,  Remove last bins with counts < 20 | GPy')
fig.tight_layout()
# Out:
# 01/30/2025 06:12:49 PM Number of simualtions 557
# 01/30/2025 06:12:49 PM Number of simualtions 557
# 01/30/2025 06:12:49 PM Number of simualtions 557
# 01/30/2025 06:12:49 PM Number of simualtions 557
# 01/30/2025 06:12:49 PM Number of simualtions 557
# 01/30/2025 06:12:49 PM Number of simualtions 557
# 01/30/2025 06:12:49 PM Number of simualtions 557
# 01/30/2025 06:12:49 PM Number of simualtions 557

# %%
import numpy as np
from gal_goku import plot


plot_hmf_emu = plot.PlotHmfEmu()

seed = 11

savefile = '/home/qezlou/HD2/HETDEX/cosmo/data/HMF/train/loo_L2_linear_mf_no_merge.hdf5'
fig, _ = plot_hmf_emu.loo_pred_truth(savefile=savefile, sub_sample=10, seed=seed)
fig.suptitle('Remove last bins with counts < 20 | Train All Linear MF')
fig.tight_layout()

fig, _ = plot_hmf_emu.loo_pred_truth(savefile=savefile, sub_sample=21, seed=seed, plot_all=True)
# Out:
# 02/05/2025 07:28:59 PM Number of simualtions 21
# 02/05/2025 07:28:59 PM Number of simualtions 21
# 02/05/2025 07:28:59 PM Number of simualtions 21
# 02/05/2025 07:29:00 PM Number of simualtions 21
# 02/05/2025 07:29:00 PM Number of simualtions 21
# 02/05/2025 07:29:00 PM Number of simualtions 21
# 02/05/2025 07:29:00 PM sim_nums = 21, panels = 6, rows = 2, columns = 3
# 02/05/2025 07:29:00 PM sim_nums = 21, panels = 6, rows = 2, columns = 3
# 02/05/2025 07:29:00 PM sim_nums = 21, panels = 6, rows = 2, columns = 3

# %% [markdown]
# More spline coefficients:

# %%
import numpy as np
from gal_goku import plot


plot_hmf_emu = plot.PlotHmfEmu()

seed = 11

savefile = '/home/qezlou/HD2/HETDEX/cosmo/data/HMF/train/loo_L2_linear_mf_no_merge_fixed_spline.hdf5'
fig, _ = plot_hmf_emu.loo_pred_truth(savefile=savefile, sub_sample=10, seed=seed)
fig.suptitle('Remove last bins with counts < 20 | Train All Linear MF')
fig.tight_layout()

fig, _ = plot_hmf_emu.loo_pred_truth(savefile=savefile, sub_sample=21, seed=seed, plot_all=True)
# Out:
# 02/11/2025 08:53:25 AM Number of simualtions 21
# 02/11/2025 08:53:25 AM Number of simualtions 21
# 02/11/2025 08:53:26 AM Number of simualtions 21
# 02/11/2025 08:53:26 AM Number of simualtions 21
# 02/11/2025 08:53:26 AM sim_nums = 21, panels = 6, rows = 2, columns = 3
# 02/11/2025 08:53:26 AM sim_nums = 21, panels = 6, rows = 2, columns = 3

# %%
import numpy as np
from gal_goku import plot


plot_hmf_emu = plot.PlotHmfEmu()

seed = 11

savefile = '/home/qezlou/HD2/HETDEX/cosmo/data/HMF/train/loo_L2_non_linear_mf_no_merge_fixed_spline.hdf5'
fig, _ = plot_hmf_emu.loo_pred_truth(savefile=savefile, sub_sample=10, seed=seed)
fig.suptitle('Remove last bins with counts < 20 | Train All Linear MF')
fig.tight_layout()

fig, _ = plot_hmf_emu.loo_pred_truth(savefile=savefile, sub_sample=21, seed=seed, plot_all=True)
# Out:
# 02/11/2025 10:40:21 AM Number of simualtions 21
# 02/11/2025 10:40:21 AM Number of simualtions 21
# 02/11/2025 10:40:21 AM Number of simualtions 21
# 02/11/2025 10:40:21 AM Number of simualtions 21
# 02/11/2025 10:40:21 AM Number of simualtions 21
# 02/11/2025 10:40:21 AM Number of simualtions 21
# 02/11/2025 10:40:21 AM sim_nums = 21, panels = 6, rows = 2, columns = 3
# 02/11/2025 10:40:21 AM sim_nums = 21, panels = 6, rows = 2, columns = 3
# 02/11/2025 10:40:21 AM sim_nums = 21, panels = 6, rows = 2, columns = 3

# %% [markdown]
# # Non-Linear MF:

# %%
import numpy as np
from gal_goku import plot


plot_hmf_emu = plot.PlotHmfEmu()

seed = 11

savefile = '/home/qezlou/HD2/HETDEX/cosmo/data/HMF/train/loo_L2_non_linear_mf_no_merge.hdf5'
fig, _ = plot_hmf_emu.loo_pred_truth(savefile=savefile, sub_sample=10, seed=seed)
fig.suptitle('Remove last bins with counts < 20 | Train All Linear MF')
fig.tight_layout()

fig, _ = plot_hmf_emu.loo_pred_truth(savefile=savefile, sub_sample=21, seed=seed, plot_all=True)
# Out:
# 02/05/2025 07:26:22 PM Number of simualtions 21
# 02/05/2025 07:26:22 PM Number of simualtions 21
# 02/05/2025 07:26:23 PM Number of simualtions 21
# 02/05/2025 07:26:23 PM Number of simualtions 21
# 02/05/2025 07:26:23 PM sim_nums = 21, panels = 6, rows = 2, columns = 3
# 02/05/2025 07:26:23 PM sim_nums = 21, panels = 6, rows = 2, columns = 3

# %% [markdown]
# More spline coefficients:

# %%
import numpy as np
from gal_goku import plot


plot_hmf_emu = plot.PlotHmfEmu()

seed = 11

savefile = '/home/qezlou/HD2/HETDEX/cosmo/data/HMF/train/loo_L2_non_linear_mf_no_merge_fixed_spline.hdf5'
fig, _ = plot_hmf_emu.loo_pred_truth(savefile=savefile, sub_sample=10, seed=seed)
fig.suptitle('Remove last bins with counts < 20 | Train All Linear MF')
fig.tight_layout()

fig, _ = plot_hmf_emu.loo_pred_truth(savefile=savefile, sub_sample=21, seed=seed, plot_all=True)
# Out:
# 02/11/2025 10:45:09 AM Number of simualtions 21
# 02/11/2025 10:45:09 AM Number of simualtions 21
# 02/11/2025 10:45:09 AM Number of simualtions 21
# 02/11/2025 10:45:09 AM Number of simualtions 21
# 02/11/2025 10:45:10 AM Number of simualtions 21
# 02/11/2025 10:45:10 AM Number of simualtions 21
# 02/11/2025 10:45:10 AM Number of simualtions 21
# 02/11/2025 10:45:10 AM Number of simualtions 21
# 02/11/2025 10:45:10 AM sim_nums = 21, panels = 6, rows = 2, columns = 3
# 02/11/2025 10:45:10 AM sim_nums = 21, panels = 6, rows = 2, columns = 3
# 02/11/2025 10:45:10 AM sim_nums = 21, panels = 6, rows = 2, columns = 3
# 02/11/2025 10:45:10 AM sim_nums = 21, panels = 6, rows = 2, columns = 3

# %% [markdown]
# ## Train on Coeffs:

# %%
import numpy as np
from gal_goku import plot


plot_hmf_emu = plot.PlotHmfEmu()

seed = 11

savefile = '/home/qezlou/HD2/HETDEX/cosmo/data/HMF/train/loo_L2_linear_mf_no_merge_on_coeffs.hdf5'

fig, _ = plot_hmf_emu.loo_pred_truth(savefile=savefile, seed=seed, plot_all=True)
# Out:
# 02/12/2025 09:37:47 PM Number of simualtions 21
# 02/12/2025 09:37:47 PM Number of simualtions 21
# 02/12/2025 09:37:47 PM Number of simualtions 21
# 02/12/2025 09:37:47 PM sim_nums = 21, panels = 6, rows = 2, columns = 3
# 02/12/2025 09:37:47 PM sim_nums = 21, panels = 6, rows = 2, columns = 3
# 02/12/2025 09:37:47 PM sim_nums = 21, panels = 6, rows = 2, columns = 3
# True

# %% [markdown]
# Non-linear:

# %%
import numpy as np
from gal_goku import plot


plot_hmf_emu = plot.PlotHmfEmu()

seed = 11

savefile = '/home/qezlou/HD2/HETDEX/cosmo/data/HMF/train/loo_L2_non_linear_mf_no_merge_on_coeffs.hdf5'

fig, _ = plot_hmf_emu.loo_pred_truth(savefile=savefile, seed=seed, plot_all=True)

# %%
from gal_goku import plot
data_dir = '/home/qezlou/HD2/HETDEX/cosmo/data/HMF/'
plt_hmf = plot.PlotHmfEmu( logging_level='ERROR')
pred, _, truth, X, eval_points =  plt_hmf.load_saved_loo('/home/qezlou/HD2/HETDEX/cosmo/data/HMF/train/loo_L2_linear_mf_no_merge_on_coeffs.hdf5')

# %%
truth.shape, pred.shape, X.shape, eval_points.shape
# Out:
# ((21, 23), (21, 23), (21, 10), (23,))

# %%
import h5py
savefile='/home/qezlou/HD2/HETDEX/cosmo/data/HMF/train/loo_L2_non_linear_mf_no_merge_on_coeffs.hdf5'
with h5py.File(savefile, 'r') as f:
    print(f.keys())
    print(f['pred'][0,:-2], f['truth'].shape, f['bins'].shape)
