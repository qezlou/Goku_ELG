# %%
import numpy as np
from gal_goku import plot


plot_hmf_emu = plot.PlotHmfEmu()

seed = 23

savefile = '/home/qezlou/HD2/HETDEX/cosmo/data/HMF/train/loo_L2_no_merge.hdf5'
fig, _ = plot_hmf_emu.loo_pred_truth(savefile=savefile, sub_sample=10, seed=seed)
fig.suptitle('Remove last bins with counts < 20 | GPFlow')
fig.tight_layout()

savefile = '/home/qezlou/HD2/HETDEX/cosmo/data/HMF/train/loo_L2_GPy_no_merge.hdf5'
fig, _ = plot_hmf_emu.loo_pred_truth(savefile=savefile, sub_sample=10, seed=seed)
fig.suptitle('LOO errors , reoptimization=1000,  Remove last bins with counts < 20 | GPy')
fig.tight_layout()
# Out:
# 01/30/2025 06:12:49 PM Number of simualtions 557
# 01/30/2025 06:12:49 PM Number of simualtions 557
# 01/30/2025 06:12:49 PM Number of simualtions 557
# 01/30/2025 06:12:49 PM Number of simualtions 557
# 01/30/2025 06:12:49 PM Number of simualtions 557
# 01/30/2025 06:12:49 PM Number of simualtions 557
# 01/30/2025 06:12:49 PM Number of simualtions 557
# 01/30/2025 06:12:49 PM Number of simualtions 557

# %%
import numpy as np
from gal_goku import plot


plot_hmf_emu = plot.PlotHmfEmu()

seed = 11

savefile = '/home/qezlou/HD2/HETDEX/cosmo/data/HMF/train/train_all_L2_mf_no_merge.hdf5'
fig, _ = plot_hmf_emu.loo_pred_truth(savefile=savefile, sub_sample=10, seed=seed)
fig.suptitle('Remove last bins with counts < 20 | Train All Linear MF')
fig.tight_layout()
# Out:
# 02/04/2025 11:46:11 PM Number of simualtions 21
# 02/04/2025 11:46:11 PM Number of simualtions 21
# 02/04/2025 11:46:11 PM Number of simualtions 21
# 02/04/2025 11:46:11 PM Number of simualtions 21
# 02/04/2025 11:46:11 PM Number of simualtions 21
# 02/04/2025 11:46:11 PM Number of simualtions 21
# 02/04/2025 11:46:11 PM Number of simualtions 21

# %%
import numpy as np
from gal_goku import plot


plot_hmf_emu = plot.PlotHmfEmu()

seed = 38

savefile = '/home/qezlou/HD2/HETDEX/cosmo/data/HMF/train/loo_L2_linear_mf_no_merge.hdf5'
fig, _ = plot_hmf_emu.loo_pred_truth(savefile=savefile, sub_sample=10, seed=seed)
fig.suptitle('Remove last bins with counts < 20 | Train All Linear MF')
fig.tight_layout()

fig, _ = plot_hmf_emu.loo_pred_truth(savefile=savefile, sub_sample=21, seed=seed, plot_all=True)
# Out:
# 02/05/2025 01:24:52 PM Number of simualtions 21
# 02/05/2025 01:24:52 PM Number of simualtions 21
# 02/05/2025 01:24:52 PM sim_nums = 21, panels = 6, rows = 2, columns = 3

# %% [markdown]
# # Non-Linear MF:

# %%
import numpy as np
from gal_goku import plot


plot_hmf_emu = plot.PlotHmfEmu()

seed = 11

savefile = '/home/qezlou/HD2/HETDEX/cosmo/data/HMF/train/traine_all_L2_non_linear_mf_no_merge.hdf5'
fig, _ = plot_hmf_emu.loo_pred_truth(savefile=savefile, sub_sample=10, seed=seed)
fig.suptitle('Remove last bins with counts < 20 | Train All Linear MF')
fig.tight_layout()

fig, _ = plot_hmf_emu.loo_pred_truth(savefile=savefile, sub_sample=21, seed=seed, plot_all=True)
# Out:
# 02/05/2025 02:36:42 PM Number of simualtions 21
# 02/05/2025 02:36:42 PM Number of simualtions 21
# 02/05/2025 02:36:43 PM Number of simualtions 21
# 02/05/2025 02:36:43 PM Number of simualtions 21
# 02/05/2025 02:36:43 PM sim_nums = 21, panels = 6, rows = 2, columns = 3
# 02/05/2025 02:36:43 PM sim_nums = 21, panels = 6, rows = 2, columns = 3

# %%
import h5py
with h5py.File(savefile, 'r') as f:
    print(f.keys())
    print(f['X'][1])
# Out:
# <KeysViewHDF5 ['X', 'bins', 'labels', 'pred', 'truth', 'var_pred']>
# [ 3.10600000e-01  4.61100000e-02  6.67733333e-01  1.05466667e-09
#   1.07660000e+00 -8.50500000e-01 -1.92433333e+00  2.24753333e+00
#   1.94000000e-02  3.86800000e-01]
