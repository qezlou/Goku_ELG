# %% [markdown]
# logspace:

# %%
import importlib
import wp_emus
import plot
import h5py
import numpy as np
import matplotlib.pyplot as plt
importlib.reload(wp_emus)

loglog_single_fid = wp_emus.LogLogSingleFid(data_dir='/home/qezlou/HD2/HETDEX/cosmo/data/corr_projected_corrected/', fid='L2', logging_level='INFO')
pred, truth, rp = loglog_single_fid.train_pred_all_sims()

plot_emu = plot.PlotProjCorrEmu()

plot_emu.pred_truth(pred, truth, rp)
# Out:
# 11/22/2024 03:20:08 PM Total snapshots: 555
# 11/22/2024 03:20:09 PM Load IC file from all_ICs.json
# 11/22/2024 03:20:09 PM X shape: (555, 10), Y shape: (555, 16), model_err shape: (555, 16)
# 11/22/2024 03:20:09 PM X shape: (555, 10), Y shape: (555, 16), model_err shape: (555, 16)
# 11/22/2024 03:20:09 PM Number of parameters: 16
# 11/22/2024 03:20:09 PM Number of parameters: 16
# 11/22/2024 03:20:09 PM moved -1 steps out of 555 sims to find a non-nan median
# 11/22/2024 03:20:09 PM moved -1 steps out of 555 sims to find a non-nan median
# 11/22/2024 03:20:09 PM None
# 11/22/2024 03:20:09 PM None
# ╒═════════════════════════╤═══════════╤══════════════════╤═════════╤═════════════╤═════════╤═════════╤════════════════╕
# │ name                    │ class     │ transform        │ prior   │ trainable   │ shape   │ dtype   │ value          │
# ╞═════════════════════════╪═══════════╪══════════════════╪═════════╪═════════════╪═════════╪═════════╪════════════════╡
# │ GPR.kernel.variance     │ Parameter │ Softplus         │         │ True        │ ()      │ float64 │ 1.0            │
# ├─────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼─────────┼─────────┼────────────────┤
# │ GPR.kernel.lengthscales │ Parameter │ Softplus         │         │ True        │ (10,)   │ float64 │ [1., 1., 1.... │
# ├─────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼─────────┼─────────┼────────────────┤
# │ GPR.likelihood.variance │ Parameter │ Softplus + Shift │         │ True        │ ()      │ float64 │ 1.0            │
# ╘═════════════════════════╧═══════════╧══════════════════╧═════════╧═════════════╧═════════╧═════════╧════════════════╛
# 11/22/2024 03:20:11 PM trained hyperparameters: lengthscales: [9.56397668e-02 2.75537914e-01 1.51484091e+03 1.01030929e-01
#  1.95220251e-01 8.91997950e-01 5.50384911e-01 5.95282660e+03
#  2.17412684e+03 2.26822354e+03]
# 11/22/2024 03:20:11 PM trained hyperparameters: lengthscales: [9.56397668e-02 2.75537914e-01 1.51484091e+03 1.01030929e-01
#  1.95220251e-01 8.91997950e-01 5.50384911e-01 5.95282660e+03
#  2.17412684e+03 2.26822354e+03]
# 11/22/2024 03:20:11 PM trained hyperparameters: variance: 1.4887612339940308
# 11/22/2024 03:20:11 PM trained hyperparameters: variance: 1.4887612339940308
# /home/qezlou/HD2/HETDEX/cosmo/pack_dev/private-HETDEX-cosmo/emu/plot.py:175: UserWarning: Attempt to set non-positive xlim on a log-scaled axis will be ignored.
#   ax.set_xlim(0, 30)

# %% [markdown]
# ## Limited LOO:
#
# Loo for ~ 1000 L2 sim takes long, let's see this for some random ones.

# %%
from gal_goku import plot

data_dir = '/home/qezlou/HD2/HETDEX/cosmo/data/corr_projected_corrected/'
plot = plot.PlotProjCorrEmu(data_dir=data_dir)
n_out = 10
plot.leave_bunch_out(data_dir, n_out=n_out)
plot.leave_bunch_out(data_dir, narrow=True, n_out=n_out)
# Out:
# 12/06/2024 05:13:05 PM Total snapshots: 1119
# 12/06/2024 05:13:05 PM Total snapshots: 1119
# 12/06/2024 05:13:05 PM Total snapshots: 1119
# 12/06/2024 05:13:05 PM Load IC file from /home/qezlou/HD2/HETDEX/cosmo/data/corr_projected_corrected/all_ICs.json
# 12/06/2024 05:13:05 PM Load IC file from /home/qezlou/HD2/HETDEX/cosmo/data/corr_projected_corrected/all_ICs.json
# 12/06/2024 05:13:05 PM Load IC file from /home/qezlou/HD2/HETDEX/cosmo/data/corr_projected_corrected/all_ICs.json
# 12/06/2024 05:13:05 PM Load IC file from /home/qezlou/HD2/HETDEX/cosmo/data/corr_projected_corrected/all_ICs.json
# 12/06/2024 05:13:05 PM Load IC file from /home/qezlou/HD2/HETDEX/cosmo/data/corr_projected_corrected/all_ICs.json
# 12/06/2024 05:13:05 PM Load IC file from /home/qezlou/HD2/HETDEX/cosmo/data/corr_projected_corrected/all_ICs.json
# 12/06/2024 05:13:05 PM Cleaning the negative bins with linear interpolation
# 12/06/2024 05:13:05 PM Cleaning the negative bins with linear interpolation
# 12/06/2024 05:13:05 PM Cleaning the negative bins with linear interpolation
# 12/06/2024 05:13:05 PM Cleaning the negative bins with linear interpolation
# 12/06/2024 05:13:05 PM Cleaning the negative bins with linear interpolation
# 12/06/2024 05:13:05 PM Leaving out 10 samples
# 12/06/2024 05:13:05 PM Leaving out 10 samples
# 12/06/2024 05:13:05 PM Leaving out 10 samples
# 12/06/2024 05:13:05 PM Training on 1109 samples
# 12/06/2024 05:13:05 PM Training on 1109 samples
# 12/06/2024 05:13:05 PM Training on 1109 samples
# 12/06/2024 05:13:12 PM Total snapshots: 1119
# 12/06/2024 05:13:12 PM Total snapshots: 1119
# 12/06/2024 05:13:12 PM Total snapshots: 1119
# 12/06/2024 05:13:12 PM Total snapshots: 1119
# 12/06/2024 05:13:12 PM Load IC file from /home/qezlou/HD2/HETDEX/cosmo/data/corr_projected_corrected/all_ICs.json
# 12/06/2024 05:13:12 PM Load IC file from /home/qezlou/HD2/HETDEX/cosmo/data/corr_projected_corrected/all_ICs.json
# 12/06/2024 05:13:12 PM Load IC file from /home/qezlou/HD2/HETDEX/cosmo/data/corr_projected_corrected/all_ICs.json
# 12/06/2024 05:13:12 PM Load IC file from /home/qezlou/HD2/HETDEX/cosmo/data/corr_projected_corrected/all_ICs.json
# 12/06/2024 05:13:13 PM Load IC file from /home/qezlou/HD2/HETDEX/cosmo/data/corr_projected_corrected/all_ICs.json
# 12/06/2024 05:13:13 PM Load IC file from /home/qezlou/HD2/HETDEX/cosmo/data/corr_projected_corrected/all_ICs.json
# 12/06/2024 05:13:13 PM Load IC file from /home/qezlou/HD2/HETDEX/cosmo/data/corr_projected_corrected/all_ICs.json
# 12/06/2024 05:13:13 PM Load IC file from /home/qezlou/HD2/HETDEX/cosmo/data/corr_projected_corrected/all_ICs.json
# 12/06/2024 05:13:13 PM Cleaning the negative bins with linear interpolation
# 12/06/2024 05:13:13 PM Cleaning the negative bins with linear interpolation
# 12/06/2024 05:13:13 PM Cleaning the negative bins with linear interpolation
# 12/06/2024 05:13:13 PM Cleaning the negative bins with linear interpolation
# 12/06/2024 05:13:13 PM Cleaning the negative bins with linear interpolation
# 12/06/2024 05:13:13 PM Cleaning the negative bins with linear interpolation
# 12/06/2024 05:13:13 PM Leaving out 10 samples
# 12/06/2024 05:13:13 PM Leaving out 10 samples
# 12/06/2024 05:13:13 PM Leaving out 10 samples
# 12/06/2024 05:13:13 PM Leaving out 10 samples
# 12/06/2024 05:13:13 PM Training on 1109 samples
# 12/06/2024 05:13:13 PM Training on 1109 samples
# 12/06/2024 05:13:13 PM Training on 1109 samples
# 12/06/2024 05:13:13 PM Training on 1109 samples

# %%
import h5py
sam_file ='/home/qezlou/HD2/HETDEX/cosmo/data/corr_projected_corrected/Zheng07_seeds_compressed_10p_Box250_Part750_0238_narrow.hdf5'
# Out:
# <KeysViewHDF5 ['corr', 'r', 'seeds']>

# %% [markdown]
# ## LOO:

# %%
import numpy as np
from glob import glob
from os import path as op
import importlib
from gal_goku import plot
importlib.reload(plot)

plot_wp_emu = plot.PlotProjCorrEmu()

seed = 3
savefile= '/home/qezlou/HD2/HETDEX/cosmo/data/corr_projected_corrected/train/loo_pred.hdf5'
plot_wp_emu.loo_pred_truth(savefile=savefile, seed=seed, title='replacing negative wp bins with  : small_number')

savefile= '/home/qezlou/HD2/HETDEX/cosmo/data/corr_projected_corrected/train/loo_pred_lin_interp.hdf5'
plot_wp_emu.loo_pred_truth(savefile=savefile, seed=seed, title='replacing negative wp bins with  : linear interpolation')

savefile= '/home/qezlou/HD2/HETDEX/cosmo/data/corr_projected_corrected/train/loo_pred_lin_interp_multi_bin.hdf5'
plot_wp_emu.loo_pred_truth(savefile=savefile, seed=seed, title='replacing negative wp bins with  : linear interpolation | GP: Multi-bin')
# Out:
# 12/10/2024 11:48:52 AM Number of simualtions 555
# 12/10/2024 11:48:52 AM Number of simualtions 555
# 12/10/2024 11:48:52 AM Number of simualtions 555
# 12/10/2024 11:48:52 AM Number of simualtions 555
# 12/10/2024 11:48:52 AM Number of simualtions 555
# 12/10/2024 11:48:52 AM Number of simualtions 555
# 12/10/2024 11:48:52 AM Number of simualtions 555
# 12/10/2024 11:48:52 AM Number of simualtions 555
# 12/10/2024 11:48:52 AM Number of simualtions 555
# 12/10/2024 11:48:52 AM Number of simualtions 555
# 12/10/2024 11:48:52 AM Number of simualtions 555
# 12/10/2024 11:48:52 AM Number of simualtions 555
# 12/10/2024 11:48:53 AM Number of simualtions 555
# 12/10/2024 11:48:53 AM Number of simualtions 555
# 12/10/2024 11:48:53 AM Number of simualtions 555
# 12/10/2024 11:48:53 AM Number of simualtions 555
# 12/10/2024 11:48:53 AM Number of simualtions 555
# 12/10/2024 11:48:53 AM Number of simualtions 555

# %% [markdown]
# Compare narrow-wide:

# %%
import numpy as np
from glob import glob
from os import path as op
import importlib
from gal_goku import plot
importlib.reload(plot)

plot_wp_emu = plot.PlotProjCorrEmu()

seed = 3

savefile = '/home/qezlou/HD2/HETDEX/cosmo/data/corr_projected_corrected/train/loo_pred_lin_interp_log_y.hdf5'
plot_wp_emu.loo_pred_truth(savefile=savefile, seed=seed, title='Goku-wide, linear interp')

savefile = '/home/qezlou/HD2/HETDEX/cosmo/data/corr_projected_corrected/train/loo_pred_lin_interp_log_y_narrow.hdf5'
plot_wp_emu.loo_pred_truth(savefile=savefile, seed=seed, title='Goku-narrow, linear interp')
# Out:
# 12/10/2024 11:52:50 AM Number of simualtions 1119
# 12/10/2024 11:52:50 AM Number of simualtions 1119
# 12/10/2024 11:52:50 AM Number of simualtions 1119
# 12/10/2024 11:52:50 AM Number of simualtions 1119
# 12/10/2024 11:52:50 AM Number of simualtions 1119
# 12/10/2024 11:52:50 AM Number of simualtions 1119
# 12/10/2024 11:52:50 AM Number of simualtions 1119
# 12/10/2024 11:52:50 AM Number of simualtions 1119
# 12/10/2024 11:52:50 AM Number of simualtions 1119
# 12/10/2024 11:52:51 AM Number of simualtions 563
# 12/10/2024 11:52:51 AM Number of simualtions 563
# 12/10/2024 11:52:51 AM Number of simualtions 563
# 12/10/2024 11:52:51 AM Number of simualtions 563
# 12/10/2024 11:52:51 AM Number of simualtions 563
# 12/10/2024 11:52:51 AM Number of simualtions 563
# 12/10/2024 11:52:51 AM Number of simualtions 563
# 12/10/2024 11:52:51 AM Number of simualtions 563
# 12/10/2024 11:52:51 AM Number of simualtions 563

# %%
import h5py
savefile = '/home/qezlou/HD2/HETDEX/cosmo/data/corr_projected_corrected/train/loo_pred_lin_interp_log_y.hdf5'
with h5py.File(savefile, 'r') as f:
    print(f.keys())
    print(f['pred'].shape)
    print(f['truth'].shape)
    print(f['rp'].shape)
# Out:
# <KeysViewHDF5 ['X', 'labels', 'pred', 'rp', 'truth', 'var_pred']>
# (1119, 16)
# (1, 1119, 16)
# (16,)

# %% [markdown]
# ## Parameter space:

# %%
import numpy as np
from glob import glob
from os import path as op
import importlib
import plot
importlib.reload(plot)

plot_wp_emu = plot.PlotProjCorrEmu()

plot_wp_emu.pred_truth_input_space(n_out=20)
# Out:
# 11/27/2024 10:56:46 AM Total snapshots: 555
# 11/27/2024 10:56:46 AM Total snapshots: 555
# 11/27/2024 10:56:46 AM Total snapshots: 555
# 11/27/2024 10:56:46 AM Total snapshots: 555
# 11/27/2024 10:56:46 AM Total snapshots: 555
# 11/27/2024 10:56:46 AM Total snapshots: 555
# 11/27/2024 10:56:46 AM Total snapshots: 555
# 11/27/2024 10:56:46 AM Total snapshots: 555
# 11/27/2024 10:56:46 AM Total snapshots: 555
# 11/27/2024 10:56:46 AM Load IC file from all_ICs.json
# 11/27/2024 10:56:46 AM Load IC file from all_ICs.json
# 11/27/2024 10:56:46 AM Load IC file from all_ICs.json
# 11/27/2024 10:56:46 AM Load IC file from all_ICs.json
# 11/27/2024 10:56:46 AM Load IC file from all_ICs.json
# 11/27/2024 10:56:46 AM Load IC file from all_ICs.json
# 11/27/2024 10:56:46 AM Load IC file from all_ICs.json
# 11/27/2024 10:56:46 AM Load IC file from all_ICs.json
# 11/27/2024 10:56:46 AM Load IC file from all_ICs.json
# 11/27/2024 10:56:46 AM X shape: (555, 10), Y shape: (555, 16), model_err shape: (555, 16)
# 11/27/2024 10:56:46 AM X shape: (555, 10), Y shape: (555, 16), model_err shape: (555, 16)
# 11/27/2024 10:56:46 AM X shape: (555, 10), Y shape: (555, 16), model_err shape: (555, 16)
# 11/27/2024 10:56:46 AM X shape: (555, 10), Y shape: (555, 16), model_err shape: (555, 16)
# 11/27/2024 10:56:46 AM X shape: (555, 10), Y shape: (555, 16), model_err shape: (555, 16)
# 11/27/2024 10:56:46 AM X shape: (555, 10), Y shape: (555, 16), model_err shape: (555, 16)
# 11/27/2024 10:56:46 AM X shape: (555, 10), Y shape: (555, 16), model_err shape: (555, 16)
# 11/27/2024 10:56:46 AM X shape: (555, 10), Y shape: (555, 16), model_err shape: (555, 16)
# 11/27/2024 10:56:46 AM X shape: (555, 10), Y shape: (555, 16), model_err shape: (555, 16)
# 11/27/2024 10:56:46 AM moved -1 steps out of 555 sims to find a non-nan median
# 11/27/2024 10:56:46 AM moved -1 steps out of 555 sims to find a non-nan median
# 11/27/2024 10:56:46 AM moved -1 steps out of 555 sims to find a non-nan median
# 11/27/2024 10:56:46 AM moved -1 steps out of 555 sims to find a non-nan median
# 11/27/2024 10:56:46 AM moved -1 steps out of 555 sims to find a non-nan median
# 11/27/2024 10:56:46 AM moved -1 steps out of 555 sims to find a non-nan median
# 11/27/2024 10:56:46 AM moved -1 steps out of 555 sims to find a non-nan median
# 11/27/2024 10:56:46 AM moved -1 steps out of 555 sims to find a non-nan median
# 11/27/2024 10:56:46 AM moved -1 steps out of 555 sims to find a non-nan median
# 11/27/2024 10:56:46 AM Leaving out 20 samples
# 11/27/2024 10:56:46 AM Leaving out 20 samples
# 11/27/2024 10:56:46 AM Leaving out 20 samples
# 11/27/2024 10:56:46 AM Leaving out 20 samples
# 11/27/2024 10:56:46 AM Leaving out 20 samples
# 11/27/2024 10:56:46 AM Leaving out 20 samples
# 11/27/2024 10:56:46 AM Leaving out 20 samples
# 11/27/2024 10:56:46 AM Leaving out 20 samples
# 11/27/2024 10:56:46 AM Leaving out 20 samples
# 11/27/2024 10:56:46 AM Training on 535 samples
# 11/27/2024 10:56:46 AM Training on 535 samples
# 11/27/2024 10:56:46 AM Training on 535 samples
# 11/27/2024 10:56:46 AM Training on 535 samples
# 11/27/2024 10:56:46 AM Training on 535 samples
# 11/27/2024 10:56:46 AM Training on 535 samples
# 11/27/2024 10:56:46 AM Training on 535 samples
# 11/27/2024 10:56:46 AM Training on 535 samples
# 11/27/2024 10:56:46 AM Training on 535 samples
# 11/27/2024 10:56:46 AM None
# 11/27/2024 10:56:46 AM None
# 11/27/2024 10:56:46 AM None
# 11/27/2024 10:56:46 AM None
# 11/27/2024 10:56:46 AM None
# 11/27/2024 10:56:46 AM None
# 11/27/2024 10:56:46 AM None
# 11/27/2024 10:56:46 AM None
# 11/27/2024 10:56:46 AM None
# ╒═════════════════════════╤═══════════╤══════════════════╤═════════╤═════════════╤═════════╤═════════╤════════════════╕
# │ name                    │ class     │ transform        │ prior   │ trainable   │ shape   │ dtype   │ value          │
# ╞═════════════════════════╪═══════════╪══════════════════╪═════════╪═════════════╪═════════╪═════════╪════════════════╡
# │ GPR.kernel.variance     │ Parameter │ Softplus         │         │ True        │ ()      │ float64 │ 1.0            │
# ├─────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼─────────┼─────────┼────────────────┤
# │ GPR.kernel.lengthscales │ Parameter │ Softplus         │         │ True        │ (10,)   │ float64 │ [1., 1., 1.... │
# ├─────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼─────────┼─────────┼────────────────┤
# │ GPR.likelihood.variance │ Parameter │ Softplus + Shift │         │ True        │ ()      │ float64 │ 1.0            │
# ╘═════════════════════════╧═══════════╧══════════════════╧═════════╧═════════════╧═════════╧═════════╧════════════════╛
# 11/27/2024 10:56:48 AM trained hyperparameters: lengthscales: [1.05486540e-01 3.24950550e-01 8.30477168e+02 7.53654526e-02
#  1.88835484e-01 4.98855481e-01 1.11818257e+03 2.30337354e+03
#  9.85926980e+02 1.59322555e+03]
# 11/27/2024 10:56:48 AM trained hyperparameters: lengthscales: [1.05486540e-01 3.24950550e-01 8.30477168e+02 7.53654526e-02
#  1.88835484e-01 4.98855481e-01 1.11818257e+03 2.30337354e+03
#  9.85926980e+02 1.59322555e+03]
# 11/27/2024 10:56:48 AM trained hyperparameters: lengthscales: [1.05486540e-01 3.24950550e-01 8.30477168e+02 7.53654526e-02
#  1.88835484e-01 4.98855481e-01 1.11818257e+03 2.30337354e+03
#  9.85926980e+02 1.59322555e+03]
# 11/27/2024 10:56:48 AM trained hyperparameters: lengthscales: [1.05486540e-01 3.24950550e-01 8.30477168e+02 7.53654526e-02
#  1.88835484e-01 4.98855481e-01 1.11818257e+03 2.30337354e+03
#  9.85926980e+02 1.59322555e+03]
# 11/27/2024 10:56:48 AM trained hyperparameters: lengthscales: [1.05486540e-01 3.24950550e-01 8.30477168e+02 7.53654526e-02
#  1.88835484e-01 4.98855481e-01 1.11818257e+03 2.30337354e+03
#  9.85926980e+02 1.59322555e+03]
# 11/27/2024 10:56:48 AM trained hyperparameters: lengthscales: [1.05486540e-01 3.24950550e-01 8.30477168e+02 7.53654526e-02
#  1.88835484e-01 4.98855481e-01 1.11818257e+03 2.30337354e+03
#  9.85926980e+02 1.59322555e+03]
# 11/27/2024 10:56:48 AM trained hyperparameters: lengthscales: [1.05486540e-01 3.24950550e-01 8.30477168e+02 7.53654526e-02
#  1.88835484e-01 4.98855481e-01 1.11818257e+03 2.30337354e+03
#  9.85926980e+02 1.59322555e+03]
# 11/27/2024 10:56:48 AM trained hyperparameters: lengthscales: [1.05486540e-01 3.24950550e-01 8.30477168e+02 7.53654526e-02
#  1.88835484e-01 4.98855481e-01 1.11818257e+03 2.30337354e+03
#  9.85926980e+02 1.59322555e+03]
# 11/27/2024 10:56:48 AM trained hyperparameters: lengthscales: [1.05486540e-01 3.24950550e-01 8.30477168e+02 7.53654526e-02
#  1.88835484e-01 4.98855481e-01 1.11818257e+03 2.30337354e+03
#  9.85926980e+02 1.59322555e+03]
# 11/27/2024 10:56:48 AM trained hyperparameters: variance: 1.540204533393665
# 11/27/2024 10:56:48 AM trained hyperparameters: variance: 1.540204533393665
# 11/27/2024 10:56:48 AM trained hyperparameters: variance: 1.540204533393665
# 11/27/2024 10:56:48 AM trained hyperparameters: variance: 1.540204533393665
# 11/27/2024 10:56:48 AM trained hyperparameters: variance: 1.540204533393665
# 11/27/2024 10:56:48 AM trained hyperparameters: variance: 1.540204533393665
# 11/27/2024 10:56:48 AM trained hyperparameters: variance: 1.540204533393665
# 11/27/2024 10:56:48 AM trained hyperparameters: variance: 1.540204533393665
# 11/27/2024 10:56:48 AM trained hyperparameters: variance: 1.540204533393665

# %% [markdown]
# This doesn't tell us much since it is not 1D paramter changes.

# %% [markdown]
# ## 1D Parameter change:

# %%
import numpy as np
from glob import glob
from os import path as op
import importlib
import plot
importlib.reload(plot)

plot_wp_emu = plot.PlotProjCorrEmu()
plot_wp_emu.param_sensitivity(cleaning_method='linear_interp')
plot_wp_emu.param_sensitivity(cleaning_method='small_number')
# Out:
# 2024-12-02 13:38:42.990327: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-12-02 13:38:43.080839: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2024-12-02 13:38:43.080859: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2024-12-02 13:38:43.106748: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-02 13:38:43.543164: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2024-12-02 13:38:43.543231: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2024-12-02 13:38:43.543239: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 12/02/2024 01:38:45 PM Total snapshots: 555
# 12/02/2024 01:38:45 PM Load IC file from all_ICs.json
# 12/02/2024 01:38:45 PM Cleaning the negative bins with linear interpolation
# 12/02/2024 01:38:45 PM Cleaning the negative bins with linear interpolation
# 12/02/2024 01:38:45 PM X shape: (555, 10), Y shape: (555, 16), model_err shape: (555, 16)
# 2024-12-02 13:38:45.930560: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2024-12-02 13:38:45.930582: W tensorflow/stream_executor/cuda/cuda_driver.cc:263] failed call to cuInit: UNKNOWN ERROR (303)
# 2024-12-02 13:38:45.930599: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (qpc): /proc/driver/nvidia/version does not exist
# 2024-12-02 13:38:45.930789: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 12/02/2024 01:38:51 PM Total snapshots: 555
# 12/02/2024 01:38:51 PM Total snapshots: 555
# 12/02/2024 01:38:51 PM Load IC file from all_ICs.json
# 12/02/2024 01:38:51 PM Load IC file from all_ICs.json
# 12/02/2024 01:38:51 PM Cleaning the negative bins with a small number
# 12/02/2024 01:38:51 PM Cleaning the negative bins with a small number
# 12/02/2024 01:38:51 PM Cleaning the negative bins with a small number
# 12/02/2024 01:38:51 PM X shape: (555, 10), Y shape: (555, 16), model_err shape: (555, 16)
# 12/02/2024 01:38:51 PM X shape: (555, 10), Y shape: (555, 16), model_err shape: (555, 16)

# %% [markdown]
# ## Test single-fid:

# %%
import importlib
import plot
import numpy as np
importlib.reload(plot)


plot_test = plot.PlotTestEmus(n_samples=700)

#plot_test.pred_truth()
plot_test.pred_truth_input_space(X=np.array([4, 9])[None, :])
plot_test.pred_truth_output_space(X=np.array([4, 9])[None, :])
# Out:
# 2024-11-25 15:12:35.907481: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-11-25 15:12:35.999594: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2024-11-25 15:12:35.999613: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2024-11-25 15:12:36.025632: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-25 15:12:36.472613: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2024-11-25 15:12:36.472676: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2024-11-25 15:12:36.472683: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 11/25/2024 03:12:38 PM X shape: (700, 2), Y shape: (700, 3), model_err shape: (700, 3)
# 11/25/2024 03:12:38 PM Number of parameters: 3
# 2024-11-25 15:12:38.670401: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2024-11-25 15:12:38.670423: W tensorflow/stream_executor/cuda/cuda_driver.cc:263] failed call to cuInit: UNKNOWN ERROR (303)
# 2024-11-25 15:12:38.670439: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (qpc): /proc/driver/nvidia/version does not exist
# 2024-11-25 15:12:38.670622: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 11/25/2024 03:12:38 PM moved -1 steps out of 700 sims to find a non-nan median
# 11/25/2024 03:12:38 PM None
# ╒═════════════════════════╤═══════════╤══════════════════╤═════════╤═════════════╤═════════╤═════════╤═════════╕
# │ name                    │ class     │ transform        │ prior   │ trainable   │ shape   │ dtype   │ value   │
# ╞═════════════════════════╪═══════════╪══════════════════╪═════════╪═════════════╪═════════╪═════════╪═════════╡
# │ GPR.kernel.variance     │ Parameter │ Softplus         │         │ True        │ ()      │ float64 │ 1.0     │
# ├─────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼─────────┼─────────┼─────────┤
# │ GPR.kernel.lengthscales │ Parameter │ Softplus         │         │ True        │ (2,)    │ float64 │ [1. 1.] │
# ├─────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼─────────┼─────────┼─────────┤
# │ GPR.likelihood.variance │ Parameter │ Softplus + Shift │         │ True        │ ()      │ float64 │ 1.0     │
# ╘═════════════════════════╧═══════════╧══════════════════╧═════════╧═════════════╧═════════╧═════════╧═════════╛
# 11/25/2024 03:12:44 PM trained hyperparameters: lengthscales: [0.24193003 0.18997713]
# 11/25/2024 03:12:44 PM trained hyperparameters: variance: 1542.8274951963524

# %% [markdown]
# ## Explore wht it SF GP fails:

# %%
import importlib
import plot
import numpy as np
importlib.reload(plot)


plot_test = plot.PlotTestEmus()

#plot_test.pred_truth()
plot_test.latent_space()
# Out:
# 2024-11-25 16:24:36.050048: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-11-25 16:24:36.140979: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2024-11-25 16:24:36.141001: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2024-11-25 16:24:36.166671: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-25 16:24:36.608881: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2024-11-25 16:24:36.608943: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2024-11-25 16:24:36.608950: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 11/25/2024 04:24:38 PM X shape: (200, 2), Y shape: (200, 3), model_err shape: (200, 3)
# 11/25/2024 04:24:38 PM Number of parameters: 3
# 2024-11-25 16:24:38.796095: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2024-11-25 16:24:38.796122: W tensorflow/stream_executor/cuda/cuda_driver.cc:263] failed call to cuInit: UNKNOWN ERROR (303)
# 2024-11-25 16:24:38.796137: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (qpc): /proc/driver/nvidia/version does not exist
# 2024-11-25 16:24:38.796320: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 11/25/2024 04:24:38 PM moved -1 steps out of 200 sims to find a non-nan median
# 11/25/2024 04:24:38 PM None
# ╒═════════════════════════╤═══════════╤══════════════════╤═════════╤═════════════╤═════════╤═════════╤═════════╕
# │ name                    │ class     │ transform        │ prior   │ trainable   │ shape   │ dtype   │ value   │
# ╞═════════════════════════╪═══════════╪══════════════════╪═════════╪═════════════╪═════════╪═════════╪═════════╡
# │ GPR.kernel.variance     │ Parameter │ Softplus         │         │ True        │ ()      │ float64 │ 1.0     │
# ├─────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼─────────┼─────────┼─────────┤
# │ GPR.kernel.lengthscales │ Parameter │ Softplus         │         │ True        │ (2,)    │ float64 │ [1. 1.] │
# ├─────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼─────────┼─────────┼─────────┤
# │ GPR.likelihood.variance │ Parameter │ Softplus + Shift │         │ True        │ ()      │ float64 │ 1.0     │
# ╘═════════════════════════╧═══════════╧══════════════════╧═════════╧═════════════╧═════════╧═════════╧═════════╛
# 11/25/2024 04:24:40 PM trained hyperparameters: lengthscales: [4.77438219 0.1245563 ]
# 11/25/2024 04:24:40 PM trained hyperparameters: variance: 69.16609072112733
