# %%
import importlib
import numpy as np
from gal_goku import summary_stats
importlib.reload(summary_stats)

data_dir = '/home/qezlou/HD2/HETDEX/cosmo/data/xi_on_grid/'
train_subdir = 'train_learn_hetero_comp_kernel'

xi = summary_stats.Xi(data_dir=data_dir, fid='HF', mass_range=(11.0, 12.5), z=2.0, narrow=False)
rbins, log_corr, corr_err, X, sim_tags = xi.get_data()
# Out:
# halo_tools not available, won't be able to use propagator.
# summary_stats | 02/02/2026 01:35:23 PM | Rank 0 | INFO  |  mass_bins = [11.  11.1 11.2 11.3 11.4 11.5 11.6 11.7 11.8 11.9 12.  12.1 12.2 12.3
#  12.4 12.5]
# summary_stats | 02/02/2026 01:35:23 PM | Rank 0 | INFO  |  mass_bins = [11.  11.1 11.2 11.3 11.4 11.5 11.6 11.7 11.8 11.9 12.  12.1 12.2 12.3
#  12.4 12.5]
# summary_stats | 02/02/2026 01:35:23 PM | Rank 0 | INFO  |  mass_bins = [11.  11.1 11.2 11.3 11.4 11.5 11.6 11.7 11.8 11.9 12.  12.1 12.2 12.3
#  12.4 12.5]
# summary_stats | 02/02/2026 01:35:23 PM | Rank 0 | INFO  |  mass_bins = [11.  11.1 11.2 11.3 11.4 11.5 11.6 11.7 11.8 11.9 12.  12.1 12.2 12.3
#  12.4 12.5]
# summary_stats | 02/02/2026 01:35:23 PM | Rank 0 | INFO  |  Found 0.1 % of xi(r,n1,n2) is nan
# summary_stats | 02/02/2026 01:35:23 PM | Rank 0 | INFO  |  Found 0.1 % of xi(r,n1,n2) is nan
# summary_stats | 02/02/2026 01:35:23 PM | Rank 0 | INFO  |  Found 0.1 % of xi(r,n1,n2) is nan
# ...

# %%
xi.xi.shape, rbins.shape, log_corr.shape, X.shape
# Out:
# ((21, 136, 50), (26,), (2856, 26), (2856, 12))
