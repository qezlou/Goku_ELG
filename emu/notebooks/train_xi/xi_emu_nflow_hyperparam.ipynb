# %%
import importlib
from gal_goku import plot
importlib.reload(plot)
import numpy as np


train_subdir = "train_nflow_improved"
norm_type = "subtract_mean"
data_dir = "/home/qezlou/HD2/HETDEX/cosmo/data/xi_on_grid/"
z = 2.5
noise_floor = 0

sims = np.array([1])

plot_xi_emu = plot.PlotXiEmu( data_dir=data_dir, 
                              sims=sims, 
                              z=z,
                              train_subdir=train_subdir)
# Out:
# Processing simulation 2/1
# [timer] predict: load attrs 0.00s
# [timer] predict: build/restore model 0.01s (device=cpu)
# [timer] predict: load checkpoint 0.02s
# samples.shape: (1, 64, 2730)
# [timer] predict: sampling + moments 9.14s (num_samples=64)

# %% [markdown]
# Even smaller model
#
# "flow_early_stopping_patience"=1000 and "flow_hidden_units": [64, 64], "bijectors":3

# %%
plot_xi_emu.cross_valid_2d_errs(mass_range=(12.3, 11.0))

# %% [markdown]
# Train smaller model:
#
# "flow_early_stopping_patience"=1000 and "flow_hidden_units": [128, 128], "bijectors":3

# %%
plot_xi_emu.cross_valid_2d_errs(mass_range=(12.3, 11.0))

# %% [markdown]
# Train smaller model:
#
# "flow_early_stopping_patience"=1000 and "flow_hidden_units": [128, 128]

# %%
plot_xi_emu.cross_valid_2d_errs(mass_range=(12.3, 11.0))

# %% [markdown]
# "flow_early_stopping_patience"=1000

# %%
plot_xi_emu.cross_valid_2d_errs(mass_range=(12.3, 11.0))

# %%
plot_xi_emu.cross_valid_2d_errs(mass_range=(12.3, 11.0))
