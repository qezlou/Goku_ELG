# %% [markdown]
# ## PCA Initialization for W in HMF:
#
# In HMF-emu : l=14 and PCA initializaiton does slightly better. So, ;et's see if thta hekps with $\xi_{gg}(r)$ emualtion power:

# %%
# Get the truth
## 1. Load the xi_Grid
import importlib
from gal_goku import plot
importlib.reload(plot)
data_dir = '/home/qezlou/HD2/HETDEX/cosmo/data/xi_on_grid/'
train_subdir = 'train_less_massive'

plot_xi_emu = plot.PlotXiEmu(data_dir=data_dir, train_subdir=train_subdir)
# Out:
# 2025-10-08 15:43:10.064875: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-10-08 15:43:10.068044: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-10-08 15:43:10.077554: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1759956190.093027  155674 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1759956190.097700  155674 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1759956190.110297  155674 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1759956190.110312  155674 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1759956190.110314  155674 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1759956190.110315  155674 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-10-08 15:43:10.114084: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Using 10 cores for parallel processing
# 2025-10-08 15:43:13.574789: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 2025-10-08 15:43:13.700920: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 2025-10-08 15:43:13.832951: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 2025-10-08 15:43:13.966621: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 2025-10-08 15:43:14.146171: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 2025-10-08 15:43:14.416204: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 2025-10-08 15:43:14.597149: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 2025-10-08 15:43:14.868581: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 2025-10-08 15:43:15.143764: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 2025-10-08 15:43:15.309293: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)

# %%
## 2. Load hmf
# Get the truth
## 1. Load the xi_Grid
import numpy as np
import importlib
from gal_goku import plot
importlib.reload(plot)
data_dir = '/home/qezlou/HD2/HETDEX/cosmo/data/'
train_subdir = 'HMF/train_pca_l14_full_comp_kernel'
num_inducing = 500
num_latents = 14
epochs = 12_000

#sims = np.delete(np.arange(36), [3])
sims =np.arange(36)
composite_kernel = ['matern32', 'matern52', 'matern32', 'matern52']

plot_hmf_emu = plot.HmfCombined(sims=sims, data_dir=data_dir, train_subdir=train_subdir, num_inducing=num_inducing, num_latents=num_latents, epochs=epochs, composite_kernel=composite_kernel)
# Out:
# summary_stats | 10/08/2025 03:44:15 PM | Rank 0 | INFO  |  loading from L2_hmfs_2.5_no_merge.hdf5
# summary_stats | 10/08/2025 03:44:15 PM | Rank 0 | INFO  |  loading from L2_hmfs_2.5_no_merge.hdf5
# summary_stats | 10/08/2025 03:44:15 PM | Rank 0 | INFO  |  loading from L2_hmfs_2.5_no_merge.hdf5
# summary_stats | 10/08/2025 03:44:15 PM | Rank 0 | INFO  |  loading from L2_hmfs_2.5_no_merge.hdf5
# summary_stats | 10/08/2025 03:44:15 PM | Rank 0 | INFO  |  loading from L2_hmfs_2.5_no_merge.hdf5
# summary_stats | 10/08/2025 03:44:15 PM | Rank 0 | INFO  |  loading from L2_hmfs_2.5_no_merge.hdf5
# summary_stats | 10/08/2025 03:44:15 PM | Rank 0 | INFO  |  loading from L2_hmfs_2.5_narrow_no_merge.hdf5
# summary_stats | 10/08/2025 03:44:15 PM | Rank 0 | INFO  |  loading from L2_hmfs_2.5_narrow_no_merge.hdf5
# summary_stats | 10/08/2025 03:44:15 PM | Rank 0 | INFO  |  loading from L2_hmfs_2.5_narrow_no_merge.hdf5
# summary_stats | 10/08/2025 03:44:15 PM | Rank 0 | INFO  |  loading from L2_hmfs_2.5_narrow_no_merge.hdf5
# summary_stats | 10/08/2025 03:44:15 PM | Rank 0 | INFO  |  loading from L2_hmfs_2.5_narrow_no_merge.hdf5
# summary_stats | 10/08/2025 03:44:15 PM | Rank 0 | INFO  |  loading from L2_hmfs_2.5_narrow_no_merge.hdf5
# summary_stats | 10/08/2025 03:44:15 PM | Rank 0 | INFO  |  loading from L2_hmfs_2.5_narrow_no_merge.hdf5
# summary_stats | 10/08/2025 03:44:15 PM | Rank 0 | INFO  |  loading from HF_hmfs_2.5_no_merge.hdf5
# summary_stats | 10/08/2025 03:44:15 PM | Rank 0 | INFO  |  loading from HF_hmfs_2.5_no_merge.hdf5
# summary_stats | 10/08/2025 03:44:15 PM | Rank 0 | INFO  |  loading from HF_hmfs_2.5_no_merge.hdf5
# summary_stats | 10/08/2025 03:44:15 PM | Rank 0 | INFO  |  loading from HF_hmfs_2.5_no_merge.hdf5
# summary_stats | 10/08/2025 03:44:15 PM | Rank 0 | INFO  |  loading from HF_hmfs_2.5_no_merge.hdf5
# summary_stats | 10/08/2025 03:44:15 PM | Rank 0 | INFO  |  loading from HF_hmfs_2.5_no_merge.hdf5
# summary_stats | 10/08/2025 03:44:15 PM | Rank 0 | INFO  |  loading from HF_hmfs_2.5_no_merge.hdf5
# summary_stats | 10/08/2025 03:44:15 PM | Rank 0 | INFO  |  loading from HF_hmfs_2.5_no_merge.hdf5
# summary_stats | 10/08/2025 03:44:15 PM | Rank 0 | INFO  |  loading from HF_hmfs_2.5_narrow_no_merge.hdf5
# summary_stats | 10/08/2025 03:44:15 PM | Rank 0 | INFO  |  loading from HF_hmfs_2.5_narrow_no_merge.hdf5
# summary_stats | 10/08/2025 03:44:15 PM | Rank 0 | INFO  |  loading from HF_hmfs_2.5_narrow_no_merge.hdf5
# summary_stats | 10/08/2025 03:44:15 PM | Rank 0 | INFO  |  loading from HF_hmfs_2.5_narrow_no_merge.hdf5
# summary_stats | 10/08/2025 03:44:15 PM | Rank 0 | INFO  |  loading from HF_hmfs_2.5_narrow_no_merge.hdf5
# summary_stats | 10/08/2025 03:44:15 PM | Rank 0 | INFO  |  loading from HF_hmfs_2.5_narrow_no_merge.hdf5
# summary_stats | 10/08/2025 03:44:15 PM | Rank 0 | INFO  |  loading from HF_hmfs_2.5_narrow_no_merge.hdf5
# summary_stats | 10/08/2025 03:44:15 PM | Rank 0 | INFO  |  loading from HF_hmfs_2.5_narrow_no_merge.hdf5
# summary_stats | 10/08/2025 03:44:15 PM | Rank 0 | INFO  |  loading from HF_hmfs_2.5_narrow_no_merge.hdf5
# 10/08/2025 03:44:15 PM Getting the predictions
# 10/08/2025 03:44:15 PM Getting the predictions
# 10/08/2025 03:44:15 PM Using 10 cores for parallel prediction
# 10/08/2025 03:44:15 PM Using 10 cores for parallel prediction
# 2025-10-08 15:44:16.087543: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 2025-10-08 15:44:16.095042: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 2025-10-08 15:44:16.138327: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 2025-10-08 15:44:16.139115: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 2025-10-08 15:44:16.146985: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 2025-10-08 15:44:16.153847: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 2025-10-08 15:44:16.155836: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 2025-10-08 15:44:16.155835: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 2025-10-08 15:44:16.156442: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 2025-10-08 15:44:16.160224: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# truth_uncen = (36, 14)

# %%
## 2. Set the true p_grid
import numpy as np
import os
from multiprocessing import Pool
from gal_goku import gal
from gal_goku import emu_cosmo
importlib.reload(gal)
importlib.reload(emu_cosmo)
from scipy.interpolate import make_interp_spline

hmf_model_file = '/home/qezlou/HD2/HETDEX/cosmo/data/HMF/train_pca_l14_full_comp_kernel/hmf_emu_combined_z2.5_inducing_500_latents_14_leave0_12000.pkl'
hmf_composite_kernel = ['matern32', 'matern52', 'matern32', 'matern52']
logging_level='ERROR'

def truth(s):
    """
    Get the truth for sim s
    """
    hmf_model_file = f'/home/qezlou/HD2/HETDEX/cosmo/data/HMF/train_pca_l14_full_comp_kernel/hmf_emu_combined_z2.5_inducing_500_latents_14_leave{s}_12000.pkl'
    g = gal.Gal(hmf_model_file, hmf_composite_kernel=hmf_composite_kernel, logging_level=logging_level)
    # Arbitrary cut to asses failing mcfit
    #g.config['r_range'] = [2, 30]
    g.reset_hod()
    g.tag_info = f'truth {s}'
    # Reser cosmo
    g.hmf = plot_hmf_emu.truth[s].squeeze()
    ind = np.where(np.isfinite(g.hmf))
    g.hmf = g.hmf[ind]
    g.log_dndlog_m_spl = make_interp_spline(np.log10(plot_hmf_emu.mbins)[ind], g.hmf)
    g.xi_grid = plot_xi_emu.truth[s].squeeze()[:,:, g.xi_emu_r_mask]
    # make the p_grid
    g.k, g.p_grid = g.xi_grid_to_p_grid()
    g.xi_hh_mth_bspline = None
    g.p_hh_mth_bspline = None
    return g

def pred(s):
    """
    Get the prediction for sim s
    """
    hmf_model_file = f'/home/qezlou/HD2/HETDEX/cosmo/data/HMF/train_pca_l14_full_comp_kernel/hmf_emu_combined_z2.5_inducing_500_latents_14_leave{s}_12000.pkl'
    g = gal.Gal(hmf_model_file, hmf_composite_kernel=hmf_composite_kernel, logging_level=logging_level)
    # Arbitrary cut to asses failing mcfit
    #g.config['r_range'] = [2, 30]
    g.reset_hod()
    g.tag_info = f'pred {s}'
    # Reser cosmo
    g.hmf = plot_hmf_emu.pred[s].squeeze()
    ind = np.where(np.isfinite(g.hmf))
    g.hmf = g.hmf[ind]
    g.log_dndlog_m_spl = make_interp_spline(np.log10(plot_hmf_emu.mbins)[ind], g.hmf)
    g.xi_grid = plot_xi_emu.pred[s].squeeze()[:,:,g.xi_emu_r_mask]
    # make the p_grid
    g.k, g.p_grid = g.xi_grid_to_p_grid()
    g.xi_hh_mth_bspline = None
    g.p_hh_mth_bspline = None
    return g


def _compare_pred_truth_xi_gg(s):
    """
    Compare the prediction and truth for xi_gg
    """
    g_truth = truth(s)
    g_pred = pred(s)
    r, xi_gg_truth = g_truth.get_xi_gg()
    _, xi_gg_pred = g_pred.get_xi_gg()
    return  r, xi_gg_truth, xi_gg_pred

def compare_pred_truth_xi_gg():
    """
    Compare the prediction and truth for xi_gg
    """
    sims = np.arange(36)
    #sims = np.delete(sims, [18])
    #sim_tags = np.delete(plot_xi_emu.sim_tags, [6, 10, 13, 16, 18])
    sim_tags = plot_xi_emu.sim_tags
    # Determine the number of cores to use (leave some cores free)
    num_cores = max(1, os.cpu_count() - 2)
    #num_cores = 1
    print(f"Using {num_cores} cores for parallel processing")
    with Pool(num_cores) as p:
        results = p.map(_compare_pred_truth_xi_gg, sims)
    r = results[0][0]
    xi_gg_truth = np.array([result[1] for result in results])
    xi_gg_pred = np.array([result[2] for result in results])
    return r, xi_gg_truth, xi_gg_pred, sim_tags

# %%
r_72, xi_gg_truth_72, xi_gg_pred_72, _ = compare_pred_truth_xi_gg()
# Out:
# Using 1 cores for parallel processing
# 2025-10-08 12:49:29.893900: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# (20,) (14, 14, 20)
# (20,) (14, 14, 20)

# %%
from scipy.interpolate import UnivariateSpline, interp1d
from matplotlib import pyplot as plt
import mcfit
fig, ax = plt.subplots(1, 2, figsize=(8, 6))
s=6
ind_m = [13,0]
r_mask =(plot_xi_emu.rbins > 0.5)*(plot_xi_emu.rbins < 50)
xi_grid = plot_xi_emu.pred[s].squeeze()[:,:,r_mask]
for s in [0, 1]:
    spl = UnivariateSpline(plot_xi_emu.rbins[r_mask], xi_grid[ind_m[0],ind_m[1]], k=3, s=s)
    min_r = 0.1
    max_r = 50
    ind_r = (r_72 >= min_r)*(r_72 <= max_r)
    r_test = r_72[ind_r]
    xi_interp = spl(r_test)
    k, p = mcfit.xi2P(r_test, l=0, lowring=True)(xi_interp, extrap=True)
    ax[0].plot(k, p, alpha=0.5, label=f'cubic spline , s={s}')

    



    ax[1].plot(r_test, xi_interp, alpha=0.5, label=f'cubic spline, s={s}')
ax[1].plot(plot_xi_emu.rbins[r_mask], xi_grid[ind_m[0],ind_m[1]], color='k', label='OG')
k_nospl, p_nospl = mcfit.xi2P(plot_xi_emu.rbins[r_mask], l=0, lowring=True)(xi_grid[ind_m[0],ind_m[1]], extrap=True)

k_nospl_over_sampled = np.logspace(np.log10(k_nospl[0]), np.log10(k_nospl[-1]), k_nospl.size*10)
p_nospl_over_sampled = UnivariateSpline( k_nospl, p_nospl, k=1, s=0)(k_nospl_over_sampled)

ax[0].plot(k_nospl, p_nospl, color='k', label='No spline')
ax[0].plot(k_nospl_over_sampled, p_nospl_over_sampled, color='C2', label='No spline (oversampled)', lw=8, alpha=0.2)
ax[0].legend()
ax[1].legend()
ax[0].set_xscale('log')
ax[0].set_yscale('log')
ax[0].set_xlabel('k [h/Mpc]')
ax[0].set_ylabel('P(k) [(Mpc/h)$^3$]')   
ax[1].set_xscale('log')
ax[1].set_yscale('log')
ax[1].set_xlabel('r [Mpc/h]')
ax[1].set_ylabel(r'$\xi(r)$')
fig.tight_layout()

# %% [markdown]
# So, cubic (even k=2) splines modify the power at small and large scales. We can simply void spline interpolating `x_grid`.
#
# - [ ]  May we should not use any moothing before transforming `p_grid` either?

# %%
k_nospl_over_sampled[-1]
# Out:
# np.float64(19.424336427063565)

# %%
np.logspace(k_nospl[0], k_nospl[-1], k_nospl.size*10)[-1]
# Out:
# np.float64(19.424336427063565)

# %%
r_trans, xi_trans = mcfit.P2xi(k_nospl, l=0, lowring=True)(p_nospl, extrap=True)

r_trans_oversampled, xi_trans_oversampled = mcfit.P2xi(k_nospl_over_sampled, l=0, lowring=True)(p_nospl_over_sampled, extrap=True)


fig, ax = plt.subplots(2, 1, figsize=(8, 6))
ax[0].plot(r_trans, xi_trans, color='C0', label=r'$H^{-1}(H(\xi_{OG}))$')
ax[0].plot(plot_xi_emu.rbins[r_mask], xi_grid[ind_m[0],ind_m[1]], color='k', marker='o', label='OG')
ax[0].plot(r_trans_oversampled, xi_trans_oversampled, color='C1', label=r'$H^{-1}(H(\xi_{OG}))$ (oversampled)')
ax[1].plot(r_trans, xi_trans/xi_grid[ind_m[0],ind_m[1]], color='C0', label=r'$H^{-1}(H(\xi_{OG})) / \xi_{OG}$')
ax[0].set_xscale('log')
ax[0].set_yscale('log')
ax[0].set_xlabel('r [Mpc/h]')
ax[0].set_ylabel(r'$\xi(r)$')
ax[1].set_xscale('log')
ax[1].set_xlabel('r [Mpc/h]')
ax[1].set_ylabel(r'$\xi(r)/\xi_{true}(r)$')
ax[1].grid(which='both', ls='dashed')
ax[1].set_yticks([0.8, 0.9, 1, 1.1, 1.2, 1.3, 1.4])
ax[1].set_ylim(0.75, 1.45)
ax[1].legend()
ax[0].legend()
fig.tight_layout()

# %% [markdown]
# - So the `FFTLog` is less accurate only on smaller scales r < 1.5 cMpc/h. Currently I don't trust the halo exclusion on those scales anyway.

# %%
from gal_goku import gal
import importlib
importlib.reload(gal)
s=6
hmf_model_file = f'/home/qezlou/HD2/HETDEX/cosmo/data/HMF/train_pca_l14_full_comp_kernel/hmf_emu_combined_z2.5_inducing_500_latents_14_leave{6}_12000.pkl'
g = gal.Gal(hmf_model_file, hmf_composite_kernel=hmf_composite_kernel, logging_level=logging_level)
# Arbitrary cut to asses failing mcfit
#g.config['r_range'] = [2, 30]
g.reset_hod()
g.tag_info = f'pred {s}'
# Reser cosmo
g.hmf = plot_hmf_emu.pred[s].squeeze()
ind = np.where(np.isfinite(g.hmf))
g.hmf = g.hmf[ind]
g.log_dndlog_m_spl = make_interp_spline(np.log10(plot_hmf_emu.mbins)[ind], g.hmf)
g.xi_grid = plot_xi_emu.pred[s].squeeze()[:,:,g.xi_emu_r_mask]
# make the p_grid
g.k, g.p_grid = g.xi_grid_to_p_grid()
# Out:
# (20,) (14, 14, 20)

# %%
from scipy.interpolate import UnivariateSpline
import mcfit

print(g.config)
fig, ax = plt.subplots(1, 2, figsize=(8, 6))

ind_m = [7,0]
#ax[0].plot(g.k, g.p_grid[ind_m[0],ind_m[1]], label=r'$H(\xi_{OG})$')
k, p = mcfit.xi2P(g.rbins, l=0, lowring=True)(g.xi_grid[ind_m[0],ind_m[1]], extrap=True)
ax[0].plot(k, p, label=r'$H(\xi_{OG})$', marker='o')


ax[1].plot(g.rbins, g.xi_grid[ind_m[0],ind_m[1]], label=r'$\xi_{OG}$', marker='o')
spl = UnivariateSpline(g.rbins, g.xi_grid[ind_m[0],ind_m[1]], k=g.config['interp_xihh_r_k'], s=g.config['interp_xihh_r_s'])
g.rbins_fine = np.logspace(np.log10(g.rbins[0]), np.log10(g.rbins[-1]), 400)
xi_interp = spl(g.rbins_fine)
k_interp, p_intep = mcfit.xi2P(g.rbins_fine, l=0, lowring=True)(xi_interp, extrap=True)
ax[0].plot(k_interp, p_intep, label=r'$H(linearly \ interpolated \ \xi_{OG})$', alpha=0.8)

ax[1].plot(g.rbins_fine, xi_interp, label=r'$linearly  \ interpolated \ \xi_{OG}$', alpha=0.8)
ax[0].plot(g.k, g.p_grid[ind_m[0],ind_m[1]], label=r'$P_{OG} \ pieline$', alpha=0.5)


for i in range(2):
    ax[i].set_xscale('log')
    ax[i].set_yscale('log')
    ax[i].legend()
ax[0].set_xlabel('k [h/Mpc]')
ax[0].set_ylabel('P(k) [(Mpc/h)$^3$]')   
ax[1].set_xlabel('r [Mpc/h]')
ax[1].set_ylabel(r'$\xi(r)$')
fig.tight_layout()
# Out:
# {'logMh': array([11.15, 11.2 , 11.25, 11.3 , 11.35, 11.4 , 11.45, 11.5 , 11.55,
#        11.6 , 11.65, 11.7 , 11.75, 11.8 , 11.85, 11.9 , 11.95, 12.  ,
#        12.05, 12.1 , 12.15, 12.2 , 12.25, 12.3 , 12.35, 12.4 , 12.45,
#        12.5 , 12.55, 12.6 , 12.65, 12.7 , 12.75, 12.8 , 12.85, 12.9 ,
#        12.95, 13.  , 13.05, 13.1 , 13.15, 13.2 , 13.25, 13.3 , 13.35,
#        13.4 ]), 'interp_xihh_r_s': 0, 'interp_xihh_r_k': 1, 'interp_phh_k_s': 0, 'interp_phh_k_k': 1, 'interp_xihh_mass_s': 0, 'interp_xihh_mass_k': 1, 'r_range': [0.5, 50], 'dm': 0.01}

# %%
g.rbins
# Out:
# array([ 0.50056595,  0.62000047,  0.76793194,  0.9511597 ,  1.17810543,
#         1.45920017,  1.80736382,  2.27499553,  2.90060912,  3.69826365,
#         4.71526961,  6.01194766,  7.66520638,  9.77310384, 12.46066368,
#        15.88729045, 20.25622426, 25.82659532, 32.9287935 , 41.98406441])

# %%
g.rbins_fine
# Out:
# array([ 0.50056595,  0.5061537 ,  0.51180382,  0.51751702,  0.52329399,
#         0.52913545,  0.53504212,  0.54101472,  0.54705399,  0.55316068,
#         0.55933554,  0.56557932,  0.57189281,  0.57827677,  0.58473199,
#         0.59125927,  0.59785942,  0.60453324,  0.61128156,  0.61810522,
#         0.62500504,  0.63198188,  0.63903661,  0.64617009,  0.6533832 ,
#         0.66067682,  0.66805187,  0.67550924,  0.68304986,  0.69067465,
#         0.69838455,  0.70618052,  0.71406352,  0.72203451,  0.73009449,
#         0.73824443,  0.74648535,  0.75481827,  0.7632442 ,  0.77176419,
#         0.78037929,  0.78909055,  0.79789906,  0.8068059 ,  0.81581216,
#         0.82491896,  0.83412742,  0.84343867,  0.85285386,  0.86237415,
#         0.87200071,  0.88173474,  0.89157742,  0.90152998,  0.91159363,
#         0.92176963,  0.93205921,  0.94246366,  0.95298426,  0.96362229,
#         0.97437907,  0.98525593,  0.99625421,  1.00737526,  1.01862045,
#         1.02999117,  1.04148882,  1.05311481,  1.06487059,  1.07675759,
#         1.08877729,  1.10093116,  1.11322071,  1.12564744,  1.13821288,
#         1.1509186 ,  1.16376614,  1.17675711,  1.18989308,  1.2031757 ,
#         1.21660658,  1.23018739,  1.24391981,  1.25780551,  1.27184622,
#         1.28604367,  1.3003996 ,  1.31491578,  1.329594  ,  1.34443608,
#         1.35944383,  1.37461912,  1.3899638 ,  1.40547978,  1.42116895,
#         1.43703327,  1.45307467,  1.46929515,  1.48569669,  1.50228131,
#         1.51905107,  1.53600803,  1.55315428,  1.57049193,  1.58802311,
#         1.60575   ,  1.62367476,  1.64179962,  1.6601268 ,  1.67865857,
#         1.69739721,  1.71634502,  1.73550434,  1.75487754,  1.77446699,
#         1.79427513,  1.81430437,  1.8345572 ,  1.85503611,  1.87574363,
#         1.89668229,  1.9178547 ,  1.93926345,  1.96091118,  1.98280056,
#         2.00493429,  2.0273151 ,  2.04994574,  2.072829  ,  2.0959677 ,
#         2.1193647 ,  2.14302288,  2.16694515,  2.19113446,  2.21559379,
#         2.24032616,  2.26533462,  2.29062224,  2.31619214,  2.34204747,
#         2.36819143,  2.39462722,  2.42135812,  2.4483874 ,  2.47571842,
#         2.50335452,  2.53129912,  2.55955567,  2.58812764,  2.61701855,
#         2.64623197,  2.67577149,  2.70564076,  2.73584346,  2.7663833 ,
#         2.79726406,  2.82848953,  2.86006357,  2.89199007,  2.92427296,
#         2.95691621,  2.98992386,  3.02329997,  3.05704865,  3.09117407,
#         3.12568042,  3.16057196,  3.19585299,  3.23152786,  3.26760096,
#         3.30407674,  3.3409597 ,  3.37825437,  3.41596536,  3.45409731,
#         3.49265493,  3.53164295,  3.5710662 ,  3.61092952,  3.65123783,
#         3.69199609,  3.73320934,  3.77488264,  3.81702114,  3.85963002,
#         3.90271454,  3.94628001,  3.99033179,  4.03487531,  4.07991607,
#         4.12545962,  4.17151155,  4.21807756,  4.26516339,  4.31277482,
#         4.36091773,  4.40959806,  4.45882179,  4.50859501,  4.55892383,
#         4.60981448,  4.6612732 ,  4.71330635,  4.76592034,  4.81912166,
#         4.87291685,  4.92731255,  4.98231547,  5.03793237,  5.09417012,
#         5.15103564,  5.20853594,  5.26667811,  5.32546931,  5.3849168 ,
#         5.44502788,  5.50580998,  5.56727058,  5.62941726,  5.69225767,
#         5.75579956,  5.82005076,  5.88501919,  5.95071285,  6.01713984,
#         6.08430834,  6.15222664,  6.2209031 ,  6.29034619,  6.36056446,
#         6.43156656,  6.50336126,  6.57595739,  6.64936389,  6.72358983,
#         6.79864434,  6.87453667,  6.95127618,  7.02887232,  7.10733466,
#         7.18667286,  7.2668967 ,  7.34801607,  7.43004096,  7.51298149,
#         7.59684787,  7.68165044,  7.76739965,  7.85410606,  7.94178037,
#         8.03043337,  8.120076  ,  8.21071929,  8.30237442,  8.39505268,
#         8.4887655 ,  8.58352443,  8.67934113,  8.77622742,  8.87419524,
#         8.97325667,  9.0734239 ,  9.17470928,  9.2771253 ,  9.38068457,
#         9.48539987,  9.59128408,  9.69835027,  9.80661162,  9.91608148,
#        10.02677333, 10.13870083, 10.25187775, 10.36631805, 10.48203584,
#        10.59904536, 10.71736105, 10.83699748, 10.95796939, 11.0802917 ,
#        11.20397947, 11.32904796, 11.45551256, 11.58338888, 11.71269265,
#        11.84343983, 11.97564652, 12.10932902, 12.2445038 , 12.38118751,
#        12.51939701, 12.65914931, 12.80046166, 12.94335145, 13.08783631,
#        13.23393403, 13.38166261, 13.53104027, 13.68208542, 13.83481666,
#        13.98925281, 14.14541292, 14.30331622, 14.46298218, 14.62443046,
#        14.78768097, 14.95275382, 15.11966935, 15.28844814, 15.45911099,
#        15.63167892, 15.80617321, 15.98261535, 16.16102709, 16.34143041,
#        16.52384755, 16.70830099, 16.89481346, 17.08340794, 17.27410768,
#        17.46693617, 17.66191718, 17.85907473, 18.05843313, 18.26001694,
#        18.463851  , 18.66996043, 18.87837063, 19.08910729, 19.30219637,
#        19.51766414, 19.73553714, 19.95584223, 20.17860655, 20.40385756,
#        20.63162302, 20.861931  , 21.09480987, 21.33028833, 21.56839541,
#        21.80916044, 22.0526131 , 22.29878339, 22.54770165, 22.79939854,
#        23.0539051 , 23.31125267, 23.57147298, 23.8345981 , 24.10066044,
#        24.3696928 , 24.64172833, 24.91680056, 25.19494338, 25.47619107,
#        25.76057829, 26.04814009, 26.3389119 , 26.63292955, 26.93022928,
#        27.23084773, 27.53482195, 27.84218938, 28.15298791, 28.46725585,
#        28.78503192, 29.10635527, 29.43126552, 29.75980269, 30.09200728,
#        30.42792022, 30.76758291, 31.11103721, 31.45832545, 31.80949041,
#        32.16457538, 32.52362412, 32.88668086, 33.25379036, 33.62499786,
#        34.00034909, 34.37989031, 34.7636683 , 35.15173036, 35.54412429,
#        35.94089847, 36.34210178, 36.74778367, 37.15799413, 37.57278371,
#        37.99220353, 38.41630528, 38.84514122, 39.27876419, 39.71722764,
#        40.16058559, 40.60889269, 41.06220418, 41.52057593, 41.98406441])

# %% [markdown]
# ## Al HF LOOCV:

# %%
r, all_xi_gg_truth, all_xi_gg_pred, sim_tags = compare_pred_truth_xi_gg()
# Out:
# Using 10 cores for parallel processing
# 2025-10-08 15:44:48.134085: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 2025-10-08 15:44:48.134085: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 2025-10-08 15:44:48.134751: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 2025-10-08 15:44:48.134751: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 2025-10-08 15:44:48.134751: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 2025-10-08 15:44:48.134751: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 2025-10-08 15:44:48.134951: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 2025-10-08 15:44:48.136797: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 2025-10-08 15:44:48.141157: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 2025-10-08 15:44:48.141433: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)

# %%
print(f'Time HOD integration takes for each cosmology {10*60/(np.ceil(72/10))} seconds')
# Out:
# Time HOD integration takes for each cosmology 75.0 seconds

# %%
r.shape, all_xi_gg_truth.shape, all_xi_gg_pred.shape, sim_tags.shape
# Out:
# ((400,), (36, 400), (36, 400), (36,))

# %%
err = np.abs(all_xi_gg_pred/all_xi_gg_truth-1)
ind_large_err = np.unique(np.where(err[:,0:200] > 0.38)[0])
print(f'sims failing due to oscillatory features after Mcfit {ind_large_err}, {sim_tags[ind_large_err]}')
# Out:
# sims failing due to oscillatory features after Mcfit [ 2 18 20], ['compressed_10p_Box1000_Part3000_0026'
#  'compressed_10p_Box1000_Part3000_0522'
#  'compressed_10p_Box1000_Part3000_0524']

# %%
from matplotlib import pyplot as plt

fig, ax = plt.subplots(2, 1, figsize=(10, 6), sharex=True, gridspec_kw={'hspace': 0, 'height_ratios': [2, 1]})

print(f'Removing sims with oscilatory features: {ind_large_err}, {sim_tags[ind_large_err]}')
sims_inds_to_use = np.delete(np.arange(36), ind_large_err)

rand_sample = np.random.choice(sims_inds_to_use, size=4, replace=False)
c=0
for i in sims_inds_to_use:
    if i in rand_sample:     
        ax[0].plot(r, all_xi_gg_truth[i], label='Truth', color=f'C{c}')
        ax[0].plot(r, all_xi_gg_pred[i], label='Pred', color=f'C{c}', ls='--')
        c+=1
    ax[1].plot(r, all_xi_gg_pred[i]/all_xi_gg_truth[i]-1, label='Pred/Truth', color=f'C0', alpha=0.4)
ax[0].set_yscale('log')
ax[0].set_xscale('log')
ax[1].set_xlabel('r [Mpc/h]')
ax[0].set_ylabel(r'$\xi_{gg}(r)$')
ax[1].set_ylabel(r'$\xi_{gg, pred}(r)/\xi_{gg, truth}(r) - 1$')
ax[0].legend()
ax[1].set_yticks([ -0.3, -0.2, -0.1, 0, 0.1, 0.2, 0.3])
ax[1].grid(which='both', ls='dashed', alpha=1.0)
fig.tight_layout()
fig.savefig('/home/qezlou/HD2/HETDEX/draft/gal-emu-paper/figures/xi_gg_loocv.pdf')
# Out:
# Removing sims with oscilatory features: [ 2 18 20], ['compressed_10p_Box1000_Part3000_0026'
#  'compressed_10p_Box1000_Part3000_0522'
#  'compressed_10p_Box1000_Part3000_0524']

# %%
from matplotlib import pyplot as plt
import numpy as np

print(f'Examining sims with large errors: {ind_large_err}, {sim_tags[ind_large_err]} - possible oscillatory features or just large LOOCV')

n_sims = len(ind_large_err)

# Create unified figure: 2 rows (main + ratio) per sim, 2 columns (xi_gg + xi_hh)
fig, axes = plt.subplots(
    nrows=n_sims * 2, ncols=2,
    figsize=(12, 3.5 * n_sims),
    sharex='col',
    gridspec_kw={'hspace': 0.3, 'wspace': 0.4}
)

for idx, sim_bad in enumerate(ind_large_err):
    ax_gg_main   = axes[2 * idx, 0]
    ax_gg_ratio  = axes[2 * idx + 1, 0]
    ax_hh_main   = axes[2 * idx, 1]
    ax_hh_ratio  = axes[2 * idx + 1, 1]

    sims_inds_to_use = [sim_bad]
    rand_sample = np.random.choice(sims_inds_to_use, size=1, replace=False)

    for c, i in enumerate(sims_inds_to_use):
        # --- xi_gg ---
        if i in rand_sample:
            ax_gg_main.plot(r, all_xi_gg_truth[i], label='Truth', color=f'C{c}')
            ax_gg_main.plot(r, all_xi_gg_pred[i], label='Pred', color=f'C{c}', ls='--')
        ax_gg_ratio.plot(r, all_xi_gg_pred[i] / all_xi_gg_truth[i] - 1, color=f'C{c}')

        # --- xi_hh ---
        if i in rand_sample:
            # Let's look at most massive bin
            ind_m = [2, 2]
            ax_hh_main.plot(plot_xi_emu.rbins, plot_xi_emu.truth[i][ind_m[0], ind_m[1]].squeeze(),
                            label=f'Truth', color=f'C{c}', marker='o')
            ax_hh_main.plot(plot_xi_emu.rbins, plot_xi_emu.pred[i][ind_m[0], ind_m[1]].squeeze(),
                            label=f'Pred', color=f'C{c}', ls='--')
        ax_hh_ratio.plot(
            plot_xi_emu.rbins,
            plot_xi_emu.pred[i][ind_m[0], ind_m[1]].squeeze() / plot_xi_emu.truth[i][ind_m[0], ind_m[1]].squeeze() - 1,
            color=f'C{c}'
        )

    # --- formatting per sim ---
    for ax in [ax_gg_main, ax_hh_main]:
        ax.set_yscale('log')
        ax.set_xscale('log')

    # Labels
    ax_gg_main.set_ylabel(r'$\xi_{gg}(r)$')
    ax_gg_ratio.set_ylabel('Pred/Truth - 1')
    ax_hh_main.set_ylabel(r'$\xi_{hh}(r)$')
    ax_hh_ratio.set_ylabel('Pred/Truth - 1')


    # Titles above each simulation group
    tag = sim_tags[sim_bad]
    ax_gg_main.set_title(f"{tag} ({sim_bad}) — xi_gg", pad=10)
    ax_hh_main.set_title(f"{tag} ({sim_bad}) — xi_hh", pad=10)

# --- Legend and global layout ---
handles, labels = ax_gg_main.get_legend_handles_labels()
fig.legend(handles, labels, loc='upper center', ncol=4, frameon=False, bbox_to_anchor=(0.5, 1.02))


fig.suptitle("Simulations with Large Errors: xi_gg & xi_hh", y=1.05, fontsize=14)
plt.subplots_adjust(top=0.93, bottom=0.05, left=0.08, right=0.97, hspace=0.45, wspace=0.3)
plt.show()
# Out:
# Examining sims with large errors: [ 2 18 20], ['compressed_10p_Box1000_Part3000_0026'
#  'compressed_10p_Box1000_Part3000_0522'
#  'compressed_10p_Box1000_Part3000_0524'] - possible oscillatory features or just large LOOCV

# %% [markdown]
# - 3 out of these 4 sims with large $\xi_{gg}$ error have already been excluded from $/xi_{hh}$ LOOCV due to having extreme cosmologies: 522-524-26.
# - Sm 72 is failing for $/xi_{gg}$ prediction due to the sharp feature at the smallest mass bin. We should be able to fix that by looking such sharp increases and plcaing a median value or something.
